# %% [markdown]
# ## Prueba panel de representación de señales (sin, cos):

# %% [markdown]
# <iframe
#     src="http://localhost:8000/toy_app.html"
#     width="100%"
#     height="450px"
#     frameborder="0"
#     style="border: 1px solid #ccc; border-radius: 4px;">
# </iframe>

# %% [markdown]
# <iframe
#     src="/SIL-JB/toy_app.html"
#     width="100%"
#     height="450px"
#     frameborder="0"
#     style="border: 1px solid #ccc; border-radius: 4px;">
# </iframe>

# %% [markdown]
# <iframe
#     src="../toy_app.html"
#     width="100%"
#     height="450px"
#     frameborder="0"
#     style="border: 1px solid #ccc; border-radius: 4px;">
# </iframe>
