# %% [markdown]
# # Definición de la transformada Z

# %% [markdown]
# En esta página, se describe brevemente la transformada Z, basándose en su comparación con la transformada de Fourier en tiempo discreto y en ventajas respecto a la misma.

# %% [markdown]
# #### Introducción
#
# La transformada Z es una alternativa al análisis de la transformada de Fourier en tiempo discreto que se basa en el uso de exponenciales complejas.
#
# Las exponenciales complejas discretas de la forma $z^n$ siendo $z=r \cdot e^{j\Omega}$ (expresada mediante módulo y fase) son autofunciones de los sistemas LTI.
#
# \begin{equation}
#  y[n]=x[n]*h[n]= \sum_{k} h[k] z_0^{n-k} = z^n \left(\sum_{k=-\infty}^{\infty} h[k]z_{0}^{-k} \right) = z_{0}^{n} H(z_0),
# \end{equation}
#
# siendo $H(z_0)$ la transformada Z de $h[n]$ evaluada en el punto $z_0=|z_0|e^{j\Omega_{0}}$.
#
# Entonces, definimos la **ecuación de análisis de la transformada Z**:
#
# :::{note .simple icon=false} Ecuación de análisis de la transformada Z
#
# \begin{equation}
#  X(z) = \sum_{n=-\infty}^{\infty}x[n] z^{-n}.
# \end{equation}
#
# :::
#
#
# En la {numref}`figs:T7:exp_compleja_ejemplo` se muestra un modelo genérico de representación en el plano Z:
#
#
# ```{figure} figures/T7/svg/z_plane.svg
# ---
# width: 70%
# name: figs:T7:exp_compleja_ejemplo
# align: center
# ---
# Representación de la exponencial compleja en el plano Z.
# ```
#
# La transformada Z se puede relacionar con la transformada de Fourier en tiempo discreto cuando el módulo de $z$ es 1 ($z=e^{j\Omega}$):
#
# \begin{equation}
#  X(z) \rightarrow \{z=e^{j\Omega}\} \rightarrow X(\Omega) = X(z).
# \end{equation}
#
# La transformada Z puede expresarse también como un caso específico de la transformada de Fourier:
#
# :::{tip .simple icon=false} Transformada Z como caso específico de transformada de Fourier
#
# \begin{equation}
#  X(z) = \sum_{n=-\infty}^{\infty} x[n]z^{-n} = \sum_{n=-\infty}^{\infty} (x[n]r^{-n})e^{-j\Omega n} = \mathcal{F} \{x[n]r^{-n}\}.
# \end{equation}
#
# :::

# %% [markdown]
# #### Ventajas de la transformada Z
# Conociendo la relación de la transformada Z con la de Fourier, recordamos de nuevo las ventajas principales de la transformada Z:
#
# 1. **Mayor existencia**. Hay señales con transformada Z que no tienen transformada de Fourier.
#
# 2. **Análisis de sistemas LTI**. A partir de la región de convergencia y la función de transferencia de la transformada Z, se pueden analizar con mayor detalle propiedades de estabilidad, causalidad e invertibilidad.
#
# 3. **Sistemas LTI descritos mediante ecuaciones en diferencias**. Con la transformada Z se pueden estudiar no solamente sistemas causales, sino también anticausales y no causales, además de sistemas no estables.

# %% [markdown]
# #### Polos y ceros
# Debido a la importancia que tienen en este tema, se muestran las fórmulas para obtener polos y ceros (usadas más adelante):
#
# :::{warning}Cálculo de polos y ceros
# - $z_0$ es un **polo** de $X(z)$ si:
# ```{math}
# \lim_{z\to z_0} |X(z)| = \infty.
# ```
# - $z_0$ es un **cero** de $X(z)$ si:
# ```{math}
# \lim_{z\to z_0} X(z) = 0.
# ```
# :::
