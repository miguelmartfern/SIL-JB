# %% [markdown]
# # Interconexión de sistemas
# Muchos sistemas complicados están construidos mediante interconexión de sistemas elementales.
#
# :::{admonition .dropdown .simple} ¿Se te occurre algún ejemplo?
#
# **Cadena musical**
#
# Interconexión de: sintonizador de radio, reproductor de CD, pletinas, amplificador, altavoces.
# :::
#
#
# ## Serie o cascada
#
# La entrada del segundo sistema es la salida del primero.
#
# Diagrama de bloques:
#
# ```{figure} figures/T1/serie.png
# ---
# width: 60%
# ---
# ```
# :::{admonition .dropdown .simple} ¿Se te occurre algún ejemplo?
#
# Receptor de radio seguido de amplificador.
# :::
#
#
# ## Paralelo
# Se suma la salida de cada sistema correspondiente a la misma señal de entrada.
#
# Diagrama de bloques:
#
# ```{figure} figures/T1/paralelo.png
# ---
# width: 60%
# ---
# ```
# :::{admonition .dropdown .simple} ¿Se te occurre algún ejemplo?
#
# Dos micrófonos conectados a un amplificador.
# :::
#
#
# ## Realimentación
# Un sistema controla a otro a partir de su salida.
#
# Diagrama de bloques:
#
# ```{figure} figures/T1/realimentacion.png
# ---
# width: 60%
# ---
# ```
# :::{admonition .dropdown .simple} ¿Se te occurre algún ejemplo?
#
# Regulador de velocidad del automóvil: ajusta el flujo de combustible para mantener la velocidad constante.
# :::
