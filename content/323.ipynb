# %% [markdown]
# (sec:T3:SF:convergencia)=
# ### Convergencia de la serie de Fourier
#
# La serie de Fourier proporciona una representación adecuada de una señal periódica siempre que ésta tenga **potencia finita**. En particular, para una señal periódica $\tilde{x}(t)$ de período fundamental $T_0$:
#
# :::{important .simple icon=false} Potencia finita
# ```{math}
# 	P_\infty = \frac{1}{T_0}\int_{\langle T_0 \rangle} |\tilde{x}(t)|^2\,dt < \infty.
# ```
# :::
#
# En este caso, la suma de un número creciente de armónicos permite aproximar progresivamente la señal original. Si se considera la aproximación parcial de orden $N$,
# ```{math}
# 	\tilde{x}_N(t) = \sum_{k=-N}^{N} c_k\,e^{jk\omega_0 t},
# ```
#
# el error cuadrático medio entre la señal y su representación espectral,
# ```{math}
# 	\varepsilon_N = \frac{1}{T_0}\int_{\langle T_0 \rangle} \bigl|\tilde{x}(t)-\tilde{x}_N(t)\bigr|^2\,dt,
# ```
# disminuye al aumentar el número de términos considerados en la serie, de forma que
# ```{math}
# 	\lim_{N\to\infty} \varepsilon_N = 0.
# ```
#
# Este resultado pone de manifiesto que la serie de Fourier reproduce correctamente el comportamiento global de la señal y su contenido espectral, aunque la convergencia no tiene por qué ser puntual en todos los instantes de tiempo.
#
# En señales que presentan discontinuidades pueden aparecer oscilaciones locales en las proximidades de dichas discontinuidades, fenómeno conocido como fenómeno de Gibbs, que no desaparece al aumentar el número de armónicos, pero queda confinado a un entorno reducido alrededor de los puntos de discontinuidad (ver Figura~\ref{fig:gibbs}).
#
# Bajo condiciones adicionales de regularidad, conocidas como condiciones de Dirichlet, puede garantizarse además la convergencia puntual de la serie de Fourier. En particular, dichas condiciones establecen que:
#
# :::{important .simple icon=false} Condiciones de Dirichlet
# * La señal es absolutamente integrable en un período,
# ```{math}
#     \frac{1}{T_0}\int_{\langle T_0 \rangle} |\tilde{x}(t)|\,dt < \infty.
# ```
# - La señal presenta un número finito de máximos y mínimos en cada período.
# - La señal presenta un número finito de discontinuidades de salto finito en cada período.
# :::
#
# En este caso, la serie de Fourier converge al valor de la señal en los puntos de continuidad y al valor medio de los límites laterales en los puntos de discontinuidad.

# %%
import numpy as np
from bokeh.plotting import figure, show, output_notebook
from bokeh.models import ColumnDataSource, CustomJS, Slider, BoxAnnotation, Div, Arrow, NormalHead, Label, LabelSet, Span
from bokeh.layouts import column, row
from myst_nb import glue

output_notebook()

# ==============================================================================
# 1. DATOS PRE-CALCULADOS (Periodo T=2)
# ==============================================================================
# Aumentamos un poco la resolución a 5000 para que la vertical sea perfecta
t = np.linspace(-1.0, 2.5, 5000)
# Señal ideal: signo de seno(pi * t) para T=2
square_wave_ideal = np.sign(np.sin(np.pi * t))

def fourier_square_sum(t, n_harmonics):
    approximation = np.zeros_like(t)
    for k in range(1, n_harmonics + 1, 2):
        approximation += np.sin(k * np.pi * t) / k
    approximation *= (4 / np.pi)
    return approximation

N_values = [1, 3, 5, 7, 9, 11, 13, 15, 19, 25, 35, 51, 75, 101, 151, 201, 251]

# Estructuras de datos
data_dict = {'t': t, 'ideal': square_wave_ideal}
peak_data = {} 
zoom_limits = {} 

for n in N_values:
    y_vals = fourier_square_sum(t, n)
    data_dict[f'y_{n}'] = y_vals
    
    # --- CÁLCULO DEL PICO ---
    search_indices = np.where((t > 0) & (t < 0.5))[0] 
    local_y = y_vals[search_indices]
    
    if len(local_y) > 0:
        max_idx_local = np.argmax(local_y)
        max_val = local_y[max_idx_local]
        max_t = t[search_indices[max_idx_local]]
        overshoot_pct = (max_val - 1.0) * 100
        label_text = f"Max: {max_val:.3f} (+{overshoot_pct:.1f}%)"
    else:
        max_t = 0.5; max_val = 4/np.pi; label_text = f"Max: {max_val:.3f}"

    peak_data[f'p_{n}'] = {'t': [max_t], 'y': [max_val], 'text': [label_text]}
    
    # --- LÍMITES ZOOM ---
    if n < 9:
        zoom_limits[f'z_{n}'] = {'xs': -0.2, 'xe': max_t + 0.2, 'ys': -0.2, 'ye': 1.5}
    else:
        zoom_limits[f'z_{n}'] = {'xs': -0.05, 'xe': 0.2, 'ys': 0.8, 'ye': 1.25}

source = ColumnDataSource(data=dict(t=t, ideal=square_wave_ideal, y=data_dict['y_1']))
source_peak = ColumnDataSource(data=peak_data['p_1'])

# ==============================================================================
# 2. CONFIGURACIÓN VISUAL
# ==============================================================================
COLOR_APROX = 'blue'
X_LIMIT_DRAW = 2.4 
X_LIMITS_AXIS = (-1.0, X_LIMIT_DRAW) 

# --- GRÁFICA PRINCIPAL (ANCHO 450) ---
p_main = figure(height=400, width=450, tools="pan,wheel_zoom,reset",
                x_range=(-1.0, X_LIMIT_DRAW + 0.2), 
                y_range=(-1.6, 2.0), title="Aproximación parcial de la serie de Fourier")

p_main.outline_line_color = None; p_main.grid.visible = False; p_main.axis.visible = False

# Ejes
p_main.segment(x0=X_LIMITS_AXIS[0], y0=0, x1=X_LIMIT_DRAW, y1=0, line_color="black", line_width=1)
p_main.add_layout(Arrow(end=NormalHead(fill_color="black", size=10), 
                        x_start=X_LIMIT_DRAW, y_start=0, x_end=X_LIMIT_DRAW + 0.1, y_end=0))
p_main.add_layout(Label(x=X_LIMIT_DRAW, y=0.1, text="t", text_font_style="italic", text_font_size="12pt"))

p_main.segment(x0=0, y0=-1.5, x1=0, y1=1.8, line_color="black", line_width=1)
p_main.add_layout(Arrow(end=NormalHead(fill_color="black", size=10), x_start=0, y_start=1.8, x_end=0, y_end=1.9))
p_main.add_layout(Label(x=0.1, y=1.8, text=r"$$\tilde{x}_N(t)$$", text_font_size="11pt"))

# Ticks
for i in [1, 2]:
    p_main.add_layout(Label(x=i, y=-0.2, text=str(i), text_align="center", text_font_size="10pt"))
for j in [-1, 1]:
    p_main.add_layout(Label(x=-0.15, y=j, text=str(j), text_align="right", text_baseline="middle", text_font_size="10pt"))
p_main.add_layout(Label(x=-0.1, y=-0.2, text="0", text_font_size="10pt"))

# --- FÓRMULA DINÁMICA (FUENTE 9pt) ---
N_init = N_values[0]
latex_text_init = r"$$\tilde{x}_{" + str(N_init) + r"}(t) = \sum_{k=-" + str(N_init) + r"}^{" + str(N_init) + r"} c_k e^{jk\pi t}$$"
formula_label = Label(x=0.6, y=1.3, text=latex_text_init, text_font_size="9pt", text_color="#333")
p_main.add_layout(formula_label)

# --- CURVAS (PRINCIPAL) ---
p_main.line('t', 'ideal', source=source, color="black", alpha=0.3, line_width=1.5, line_dash="dashed", legend_label="Ideal")
p_main.line('t', 'y', source=source, color=COLOR_APROX, line_width=2, legend_label="Aprox")

# Sombreado Error (Último para la leyenda)
p_main.varea(x='t', y1='ideal', y2='y', source=source, 
             fill_color="red", fill_alpha=0.2, legend_label="Error")

init_zoom = zoom_limits['z_1']
zoom_box = BoxAnnotation(left=init_zoom['xs'], right=init_zoom['xe'], bottom=init_zoom['ys'], top=init_zoom['ye'], 
                         fill_color="gray", fill_alpha=0.1, line_color="gray", line_dash="dotted")
p_main.add_layout(zoom_box)
p_main.legend.location = "top_right"; p_main.legend.click_policy = "hide"; p_main.legend.border_line_color = None

# --- GRÁFICA ZOOM (ANCHO 200) ---
p_zoom = figure(title="Zoom Dinámico", height=400, width=200, 
                x_range=(init_zoom['xs'], init_zoom['xe']), 
                y_range=(init_zoom['ys'], init_zoom['ye']), 
                tools="", toolbar_location=None,
                background_fill_color="white", border_fill_color="white")

# CORRECCIÓN AQUÍ: Quitamos el Span infinito y dibujamos la señal ideal real
# Esto crea el escalón vertical en t=0 y limita la línea a t>0 (donde es 1) y t<0 (donde es -1)
p_zoom.line('t', 'ideal', source=source, color="black", alpha=0.3, line_width=1.5, line_dash="dashed")

p_zoom.varea(x='t', y1='ideal', y2='y', source=source, fill_color="red", fill_alpha=0.2)
p_zoom.line('t', 'y', source=source, color=COLOR_APROX, line_width=3)
p_zoom.scatter('t', 'y', source=source_peak, size=8, color="red", marker="circle")
labels = LabelSet(x='t', y='y', text='text', source=source_peak, 
                  text_font_size="8pt", text_color="red", x_offset=-60, y_offset=5, text_align="left")
p_zoom.add_layout(labels)
p_zoom.xaxis.axis_label = "t"; p_zoom.grid.grid_line_color = "#eeeeee"

# ==============================================================================
# 3. INTERACTIVIDAD
# ==============================================================================
div_info = Div(text=f"<h3 style='margin-bottom:0px; color:#333'>Armónicos: N = {N_values[0]}</h3>", width=300)
slider = Slider(start=0, end=len(N_values)-1, value=0, step=1, title="", sizing_mode="stretch_width", show_value=False) 

callback = CustomJS(args=dict(source=source, source_peak=source_peak, slider=slider, div=div_info, 
                              all_data=data_dict, all_peaks=peak_data, all_lims=zoom_limits, 
                              N_vals=N_values, p_zoom=p_zoom, zoom_box=zoom_box,
                              formula_label=formula_label), code="""
    const idx = slider.value;
    const N = N_vals[idx];
    const data = source.data;
    const y_new = all_data['y_' + N];
    for (let i = 0; i < data['y'].length; i++) { data['y'][i] = y_new[i]; }
    
    const peak_curr = all_peaks['p_' + N];
    source_peak.data = { 't': peak_curr['t'], 'y': peak_curr['y'], 'text': peak_curr['text'] };
    
    const lims = all_lims['z_' + N];
    p_zoom.x_range.start = lims.xs; p_zoom.x_range.end = lims.xe;
    p_zoom.y_range.start = lims.ys; p_zoom.y_range.end = lims.ye;
    zoom_box.left = lims.xs; zoom_box.right = lims.xe; zoom_box.bottom = lims.ys; zoom_box.top = lims.ye;
    
    div.text = "<h3 style='margin-bottom:0px; color:#333'>Armónicos: N = " + N + "</h3>";
    
    formula_label.text = "$$\\\\tilde{x}_{" + N + "}(t) = \\\\sum_{k=-" + N + "}^{" + N + "} c_k e^{jk\\\\pi t}$$";

    source.change.emit(); source_peak.change.emit();
""")

slider.js_on_change('value', callback)

layout_final = column(
    div_info,
    slider,
    row(p_main, p_zoom, sizing_mode="scale_width"), 
    sizing_mode="scale_width"
)

# --- CAMBIO AL FINAL ---
# En lugar de show(layout_final), usamos glue:
# 1. "gibbs_plot": Es el nombre clave que usaremos luego en el Markdown.
# 2. layout_final: Tu figura.
# 3. display=False: Para que no salga duplicada fuera del bloque warning.

glue("gibbs_plot", layout_final, display=False)
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="e92e7162-0810-4159-b9ed-88dd4fd7ded1">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# :::{warning} Fenómeno de Gibbs
# Aquí podemos observar cómo la aproximación oscila alrededor de la discontinuidad.
#
# ```{glue:figure} gibbs_plot
# :name: "figura-gibbs"
# :align: "center"
#
# Fíjate que aunque aumentes $N$, el error máximo (zona roja) nunca desaparece, solo se hace más estrecho.
# :::

# %% [markdown]
# :::{warning} Fenómeno de Gibbs
# La figura muestra cómo el error se concentra en la discontinuidad.
#
# {glue:figure}`gibbs_plot`
#
# Fíjate que aunque aumentes N, el error máximo nunca desaparece.
# :::

# %%
import sys
from pathlib import Path

# --- CONFIGURACIÓN ---
# Añade aquí las carpetas que quieras ignorar
IGNORE_DIRS = {'.git', '__pycache__', 'venv', 'env', '.idea', '.vscode', 'node_modules'}

def generate_tree(dir_path: Path, prefix: str = ""):
    """
    Genera un generador que yield strings para el árbol de directorios.
    """
    try:
        # Obtener contenidos y ordenarlos (carpetas y archivos juntos alfabéticamente)
        # Si quieres carpetas primero, cambia el sort.
        contents = list(dir_path.iterdir())
        contents.sort(key=lambda x: x.name.lower())
    except PermissionError:
        yield f"{prefix}[Acceso Denegado]"
        return

    # Filtramos las carpetas ignoradas
    contents = [
        item for item in contents 
        if item.name not in IGNORE_DIRS and not item.name.startswith('.')
    ]

    pointers = [("├── ", "│   ")] * (len(contents) - 1) + [("└── ", "    ")]

    for pointer, path in zip(pointers, contents):
        yield f"{prefix}{pointer[0]}{path.name}"
        
        if path.is_dir():
            extension = pointer[1]
            yield from generate_tree(path, prefix=prefix + extension)

def main():
    # Por defecto usa el directorio actual (.), si no, el que pases como argumento
    path_arg = sys.argv[1] if len(sys.argv) > 1 else "."
    path_arg = "E:\OneDrive - UVa\Docencia\SL\SIL-JB"
    root = Path(path_arg)
    
    if not root.exists():
        print(f"¡Error! La ruta '{root}' no existe.")
        return

    print(f"📂 {root.resolve().name}")
    for line in generate_tree(root):
        print(line)

if __name__ == "__main__":
    main()
# Out:
# 📂 SIL-JB
# ├── _build
# │   ├── logs
# │   │   └── myst.build.json
# │   ├── site
# │   │   ├── config.json
# │   │   ├── content
# │   │   │   ├── 101-andromaca-safeBackup-0001.json
# │   │   │   ├── 101-andromaca-safeBackup-0002.json
# │   │   │   ├── 101-andromaca-safeBackup-0003.json
# │   │   │   ├── 101-andromaca-safeBackup-0004.json
# │   │   │   ├── 101-andromaca-safeBackup-0005.json
# │   │   │   ├── 101-andromaca-safeBackup-0006.json
# │   │   │   ├── 101-andromaca-safeBackup-0007.json
# │   │   │   ├── 101-andromaca-safeBackup-0008.json
# │   │   │   ├── 101-andromaca-safeBackup-0009.json
# │   │   │   ├── 101-andromaca-safeBackup-0010.json
# │   │   │   ├── 101-andromaca-safeBackup-0011.json
# │   │   │   ├── 101-andromaca-safeBackup-0012.json
# │   │   │   ├── 101-andromaca-safeBackup-0013.json
# │   │   │   ├── 101-andromaca-safeBackup-0014.json
# │   │   │   ├── 101-andromaca-safeBackup-0015.json
# │   │   │   ├── 101-andromaca-safeBackup-0016.json
# │   │   │   ├── 101-andromaca-safeBackup-0017.json
# │   │   │   ├── 101-andromaca-safeBackup-0018.json
# │   │   │   ├── 101-andromaca-safeBackup-0019.json
# │   │   │   ├── 101-andromaca-safeBackup-0020.json
# │   │   │   ├── 101-andromaca-safeBackup-0021.json
# │   │   │   ├── 101-andromaca-safeBackup-0022.json
# │   │   │   ├── 101-andromaca-safeBackup-0023.json
# │   │   │   ├── 101-andromaca-safeBackup-0024.json
# │   │   │   ├── 101-andromaca-safeBackup-0025.json
# │   │   │   ├── 101-andromaca-safeBackup-0026.json
# │   │   │   ├── 101-andromaca-safeBackup-0027.json
# │   │   │   ├── 101-andromaca-safeBackup-0028.json
# │   │   │   ├── 101-andromaca-safeBackup-0029.json
# │   │   │   ├── 101-andromaca-safeBackup-0030.json
# │   │   │   ├── 101-andromaca-safeBackup-0031.json
# │   │   │   ├── 101-andromaca-safeBackup-0032.json
# │   │   │   ├── 101-andromaca-safeBackup-0033.json
# │   │   │   ├── 101-andromaca-safeBackup-0034.json
# │   │   │   ├── 101-andromaca-safeBackup-0035.json
# │   │   │   ├── 101-andromaca-safeBackup-0036.json
# │   │   │   ├── 101-andromaca-safeBackup-0037.json
# │   │   │   ├── 101-andromaca-safeBackup-0038.json
# │   │   │   ├── 101-andromaca-safeBackup-0039.json
# │   │   │   ├── 101-andromaca-safeBackup-0040.json
# │   │   │   ├── 101-andromaca-safeBackup-0041.json
# │   │   │   ├── 101-andromaca-safeBackup-0042.json
# │   │   │   ├── 101-andromaca-safeBackup-0043.json
# │   │   │   ├── 101-andromaca-safeBackup-0044.json
# │   │   │   ├── 101-andromaca-safeBackup-0045.json
# │   │   │   ├── 101-andromaca-safeBackup-0046.json
# │   │   │   ├── 101-andromaca-safeBackup-0047.json
# │   │   │   ├── 101-andromaca-safeBackup-0048.json
# │   │   │   ├── 101-andromaca-safeBackup-0049.json
# │   │   │   ├── 101-andromaca-safeBackup-0050.json
# │   │   │   ├── 101-andromaca-safeBackup-0051.json
# │   │   │   ├── 101-andromaca-safeBackup-0052.json
# │   │   │   ├── 101-andromaca-safeBackup-0053.json
# │   │   │   ├── 101-andromaca-safeBackup-0054.json
# │   │   │   ├── 101-andromaca-safeBackup-0055.json
# │   │   │   ├── 101-andromaca-safeBackup-0056.json
# │   │   │   ├── 101-andromaca-safeBackup-0057.json
# │   │   │   ├── 101-andromaca-safeBackup-0058.json
# │   │   │   ├── 101-andromaca-safeBackup-0059.json
# │   │   │   ├── 101-andromaca-safeBackup-0060.json
# │   │   │   ├── 101-andromaca-safeBackup-0061.json
# │   │   │   ├── 101-andromaca-safeBackup-0062.json
# │   │   │   ├── 101-andromaca-safeBackup-0063.json
# │   │   │   ├── 101-andromaca-safeBackup-0064.json
# │   │   │   ├── 101-andromaca-safeBackup-0065.json
# │   │   │   ├── 101-andromaca-safeBackup-0066.json
# │   │   │   ├── 101-andromaca-safeBackup-0067.json
# │   │   │   ├── 101-andromaca-safeBackup-0068.json
# │   │   │   ├── 101-andromaca-safeBackup-0069.json
# │   │   │   ├── 101-andromaca-safeBackup-0070.json
# │   │   │   ├── 101-andromaca-safeBackup-0071.json
# │   │   │   ├── 101-andromaca-safeBackup-0072.json
# │   │   │   ├── 101-andromaca-safeBackup-0073.json
# │   │   │   ├── 101-andromaca-safeBackup-0074.json
# │   │   │   ├── 101-andromaca-safeBackup-0075.json
# │   │   │   ├── 101-andromaca-safeBackup-0076.json
# │   │   │   ├── 101-andromaca-safeBackup-0077.json
# │   │   │   ├── 101-andromaca-safeBackup-0078.json
# │   │   │   ├── 101-andromaca-safeBackup-0079.json
# │   │   │   ├── 101-andromaca-safeBackup-0080.json
# │   │   │   ├── 101-andromaca-safeBackup-0081.json
# │   │   │   ├── 101-andromaca-safeBackup-0082.json
# │   │   │   ├── 101-andromaca-safeBackup-0083.json
# │   │   │   ├── 101-andromaca-safeBackup-0084.json
# │   │   │   ├── 101-andromaca-safeBackup-0085.json
# │   │   │   ├── 101-andromaca-safeBackup-0086.json
# │   │   │   ├── 101-andromaca-safeBackup-0087.json
# │   │   │   ├── 101-andromaca-safeBackup-0088.json
# │   │   │   ├── 101-andromaca-safeBackup-0089.json
# │   │   │   ├── 101-andromaca-safeBackup-0090.json
# │   │   │   ├── 101-andromaca-safeBackup-0091.json
# │   │   │   ├── 101-andromaca-safeBackup-0092.json
# │   │   │   ├── 101-andromaca-safeBackup-0093.json
# │   │   │   ├── 101-andromaca-safeBackup-0094.json
# │   │   │   ├── 101-andromaca-safeBackup-0095.json
# │   │   │   ├── 101-andromaca-safeBackup-0096.json
# │   │   │   ├── 101-andromaca-safeBackup-0097.json
# │   │   │   ├── 101-andromaca-safeBackup-0098.json
# │   │   │   ├── 101-andromaca-safeBackup-0099.json
# │   │   │   ├── 101-andromaca-safeBackup-0100.json
# │   │   │   ├── 101-andromaca-safeBackup-0101.json
# │   │   │   ├── 101-andromaca-safeBackup-0102.json
# │   │   │   ├── 101-andromaca-safeBackup-0103.json
# │   │   │   ├── 101-andromaca-safeBackup-0104.json
# │   │   │   ├── 101-andromaca-safeBackup-0105.json
# │   │   │   ├── 101-andromaca-safeBackup-0106.json
# │   │   │   ├── 101-andromaca-safeBackup-0107.json
# │   │   │   ├── 101-andromaca-safeBackup-0108.json
# │   │   │   ├── 101-andromaca-safeBackup-0109.json
# │   │   │   ├── 101-andromaca-safeBackup-0110.json
# │   │   │   ├── 101-andromaca-safeBackup-0111.json
# │   │   │   ├── 101-andromaca-safeBackup-0112.json
# │   │   │   ├── 101-andromaca-safeBackup-0113.json
# │   │   │   ├── 101-andromaca-safeBackup-0114.json
# │   │   │   ├── 101-andromaca-safeBackup-0115.json
# │   │   │   ├── 101-andromaca-safeBackup-0116.json
# │   │   │   ├── 101-andromaca-safeBackup-0117.json
# │   │   │   ├── 101-andromaca-safeBackup-0118.json
# │   │   │   ├── 101-andromaca-safeBackup-0119.json
# │   │   │   ├── 101-PC-Miguel-2.json
# │   │   │   ├── 101-PC-Miguel-3.json
# │   │   │   ├── 101-PC-Miguel-4.json
# │   │   │   ├── 101-PC-Miguel-5.json
# │   │   │   ├── 101-PC-Miguel-6.json
# │   │   │   ├── 101-PC-Miguel-7.json
# │   │   │   ├── 101-PC-Miguel-8.json
# │   │   │   ├── 101-PC-Miguel.json
# │   │   │   ├── 101.json
# │   │   │   ├── 102-andromaca-safeBackup-0001.json
# │   │   │   ├── 102-andromaca-safeBackup-0002.json
# │   │   │   ├── 102-andromaca-safeBackup-0003.json
# │   │   │   ├── 102-andromaca-safeBackup-0004.json
# │   │   │   ├── 102-andromaca-safeBackup-0005.json
# │   │   │   ├── 102-andromaca-safeBackup-0006.json
# │   │   │   ├── 102-andromaca-safeBackup-0007.json
# │   │   │   ├── 102-andromaca-safeBackup-0008.json
# │   │   │   ├── 102-andromaca-safeBackup-0009.json
# │   │   │   ├── 102-andromaca-safeBackup-0010.json
# │   │   │   ├── 102-andromaca-safeBackup-0011.json
# │   │   │   ├── 102-andromaca-safeBackup-0012.json
# │   │   │   ├── 102-andromaca-safeBackup-0013.json
# │   │   │   ├── 102-andromaca-safeBackup-0014.json
# │   │   │   ├── 102-andromaca-safeBackup-0015.json
# │   │   │   ├── 102-andromaca-safeBackup-0016.json
# │   │   │   ├── 102-andromaca-safeBackup-0017.json
# │   │   │   ├── 102-andromaca-safeBackup-0018.json
# │   │   │   ├── 102-andromaca-safeBackup-0019.json
# │   │   │   ├── 102-andromaca-safeBackup-0020.json
# │   │   │   ├── 102-andromaca-safeBackup-0021.json
# │   │   │   ├── 102-andromaca-safeBackup-0022.json
# │   │   │   ├── 102-andromaca-safeBackup-0023.json
# │   │   │   ├── 102-andromaca-safeBackup-0024.json
# │   │   │   ├── 102-andromaca-safeBackup-0025.json
# │   │   │   ├── 102-andromaca-safeBackup-0026.json
# │   │   │   ├── 102-andromaca-safeBackup-0027.json
# │   │   │   ├── 102-andromaca-safeBackup-0028.json
# │   │   │   ├── 102-andromaca-safeBackup-0029.json
# │   │   │   ├── 102-andromaca-safeBackup-0030.json
# │   │   │   ├── 102-andromaca-safeBackup-0031.json
# │   │   │   ├── 102-andromaca-safeBackup-0032.json
# │   │   │   ├── 102-andromaca-safeBackup-0033.json
# │   │   │   ├── 102-andromaca-safeBackup-0034.json
# │   │   │   ├── 102-andromaca-safeBackup-0035.json
# │   │   │   ├── 102-andromaca-safeBackup-0036.json
# │   │   │   ├── 102-andromaca-safeBackup-0037.json
# │   │   │   ├── 102-andromaca-safeBackup-0038.json
# │   │   │   ├── 102-andromaca-safeBackup-0039.json
# │   │   │   ├── 102-andromaca-safeBackup-0040.json
# │   │   │   ├── 102-andromaca-safeBackup-0041.json
# │   │   │   ├── 102-andromaca-safeBackup-0042.json
# │   │   │   ├── 102-andromaca-safeBackup-0043.json
# │   │   │   ├── 102-andromaca-safeBackup-0044.json
# │   │   │   ├── 102-andromaca-safeBackup-0045.json
# │   │   │   ├── 102-andromaca-safeBackup-0046.json
# │   │   │   ├── 102-andromaca-safeBackup-0047.json
# │   │   │   ├── 102-andromaca-safeBackup-0048.json
# │   │   │   ├── 102-andromaca-safeBackup-0049.json
# │   │   │   ├── 102-andromaca-safeBackup-0050.json
# │   │   │   ├── 102-andromaca-safeBackup-0051.json
# │   │   │   ├── 102-andromaca-safeBackup-0052.json
# │   │   │   ├── 102-andromaca-safeBackup-0053.json
# │   │   │   ├── 102-andromaca-safeBackup-0054.json
# │   │   │   ├── 102-andromaca-safeBackup-0055.json
# │   │   │   ├── 102-andromaca-safeBackup-0056.json
# │   │   │   ├── 102-andromaca-safeBackup-0057.json
# │   │   │   ├── 102-andromaca-safeBackup-0058.json
# │   │   │   ├── 102-andromaca-safeBackup-0059.json
# │   │   │   ├── 102-andromaca-safeBackup-0060.json
# │   │   │   ├── 102-andromaca-safeBackup-0061.json
# │   │   │   ├── 102-andromaca-safeBackup-0062.json
# │   │   │   ├── 102-andromaca-safeBackup-0063.json
# │   │   │   ├── 102-andromaca-safeBackup-0064.json
# │   │   │   ├── 102-andromaca-safeBackup-0065.json
# │   │   │   ├── 102-andromaca-safeBackup-0066.json
# │   │   │   ├── 102-andromaca-safeBackup-0067.json
# │   │   │   ├── 102-andromaca-safeBackup-0068.json
# │   │   │   ├── 102-andromaca-safeBackup-0069.json
# │   │   │   ├── 102-andromaca-safeBackup-0070.json
# │   │   │   ├── 102-andromaca-safeBackup-0071.json
# │   │   │   ├── 102-andromaca-safeBackup-0072.json
# │   │   │   ├── 102-andromaca-safeBackup-0073.json
# │   │   │   ├── 102-andromaca-safeBackup-0074.json
# │   │   │   ├── 102-andromaca-safeBackup-0075.json
# │   │   │   ├── 102-andromaca-safeBackup-0076.json
# │   │   │   ├── 102-andromaca-safeBackup-0077.json
# │   │   │   ├── 102-andromaca-safeBackup-0078.json
# │   │   │   ├── 102-andromaca-safeBackup-0079.json
# │   │   │   ├── 102-andromaca-safeBackup-0080.json
# │   │   │   ├── 102-andromaca-safeBackup-0081.json
# │   │   │   ├── 102-andromaca-safeBackup-0082.json
# │   │   │   ├── 102-andromaca-safeBackup-0083.json
# │   │   │   ├── 102-andromaca-safeBackup-0084.json
# │   │   │   ├── 102-andromaca-safeBackup-0085.json
# │   │   │   ├── 102-andromaca-safeBackup-0086.json
# │   │   │   ├── 102-andromaca-safeBackup-0087.json
# │   │   │   ├── 102-andromaca-safeBackup-0088.json
# │   │   │   ├── 102-andromaca-safeBackup-0089.json
# │   │   │   ├── 102-andromaca-safeBackup-0090.json
# │   │   │   ├── 102-andromaca-safeBackup-0091.json
# │   │   │   ├── 102-andromaca-safeBackup-0092.json
# │   │   │   ├── 102-andromaca-safeBackup-0093.json
# │   │   │   ├── 102-andromaca-safeBackup-0094.json
# │   │   │   ├── 102-andromaca-safeBackup-0095.json
# │   │   │   ├── 102-andromaca-safeBackup-0096.json
# │   │   │   ├── 102-andromaca-safeBackup-0097.json
# │   │   │   ├── 102-andromaca-safeBackup-0098.json
# │   │   │   ├── 102-andromaca-safeBackup-0099.json
# │   │   │   ├── 102-andromaca-safeBackup-0100.json
# │   │   │   ├── 102-andromaca-safeBackup-0101.json
# │   │   │   ├── 102-andromaca-safeBackup-0102.json
# │   │   │   ├── 102-andromaca-safeBackup-0103.json
# │   │   │   ├── 102-andromaca-safeBackup-0104.json
# │   │   │   ├── 102-andromaca-safeBackup-0105.json
# │   │   │   ├── 102-andromaca-safeBackup-0106.json
# │   │   │   ├── 102-andromaca-safeBackup-0107.json
# │   │   │   ├── 102-andromaca-safeBackup-0108.json
# │   │   │   ├── 102-andromaca-safeBackup-0109.json
# │   │   │   ├── 102-andromaca-safeBackup-0110.json
# │   │   │   ├── 102-andromaca-safeBackup-0111.json
# │   │   │   ├── 102-andromaca-safeBackup-0112.json
# │   │   │   ├── 102-andromaca-safeBackup-0113.json
# │   │   │   ├── 102-andromaca-safeBackup-0114.json
# │   │   │   ├── 102-andromaca-safeBackup-0115.json
# │   │   │   ├── 102-andromaca-safeBackup-0116.json
# │   │   │   ├── 102-andromaca-safeBackup-0117.json
# │   │   │   ├── 102-andromaca-safeBackup-0118.json
# │   │   │   ├── 102-andromaca-safeBackup-0119.json
# │   │   │   ├── 102-andromaca-safeBackup-0120.json
# │   │   │   ├── 102-andromaca-safeBackup-0121.json
# │   │   │   ├── 102-andromaca-safeBackup-0122.json
# │   │   │   ├── 102-andromaca-safeBackup-0123.json
# │   │   │   ├── 102-andromaca-safeBackup-0124.json
# │   │   │   ├── 102-andromaca-safeBackup-0125.json
# │   │   │   ├── 102-andromaca-safeBackup-0126.json
# │   │   │   ├── 102-PC-Miguel-10.json
# │   │   │   ├── 102-PC-Miguel-11.json
# │   │   │   ├── 102-PC-Miguel-2.json
# │   │   │   ├── 102-PC-Miguel-3.json
# │   │   │   ├── 102-PC-Miguel-4.json
# │   │   │   ├── 102-PC-Miguel-5.json
# │   │   │   ├── 102-PC-Miguel-6.json
# │   │   │   ├── 102-PC-Miguel-7.json
# │   │   │   ├── 102-PC-Miguel-8.json
# │   │   │   ├── 102-PC-Miguel-9.json
# │   │   │   ├── 102-PC-Miguel.json
# │   │   │   ├── 102.json
# │   │   │   ├── 103-andromaca-safeBackup-0001.json
# │   │   │   ├── 103-andromaca-safeBackup-0002.json
# │   │   │   ├── 103-andromaca-safeBackup-0003.json
# │   │   │   ├── 103-andromaca-safeBackup-0004.json
# │   │   │   ├── 103-andromaca-safeBackup-0005.json
# │   │   │   ├── 103-andromaca-safeBackup-0006.json
# │   │   │   ├── 103-andromaca-safeBackup-0007.json
# │   │   │   ├── 103-andromaca-safeBackup-0008.json
# │   │   │   ├── 103-andromaca-safeBackup-0009.json
# │   │   │   ├── 103-andromaca-safeBackup-0010.json
# │   │   │   ├── 103-andromaca-safeBackup-0011.json
# │   │   │   ├── 103-andromaca-safeBackup-0012.json
# │   │   │   ├── 103-andromaca-safeBackup-0013.json
# │   │   │   ├── 103-andromaca-safeBackup-0014.json
# │   │   │   ├── 103-andromaca-safeBackup-0015.json
# │   │   │   ├── 103-andromaca-safeBackup-0016.json
# │   │   │   ├── 103-andromaca-safeBackup-0017.json
# │   │   │   ├── 103-andromaca-safeBackup-0018.json
# │   │   │   ├── 103-andromaca-safeBackup-0019.json
# │   │   │   ├── 103-andromaca-safeBackup-0020.json
# │   │   │   ├── 103-andromaca-safeBackup-0021.json
# │   │   │   ├── 103-andromaca-safeBackup-0022.json
# │   │   │   ├── 103-andromaca-safeBackup-0023.json
# │   │   │   ├── 103-andromaca-safeBackup-0024.json
# │   │   │   ├── 103-andromaca-safeBackup-0025.json
# │   │   │   ├── 103-andromaca-safeBackup-0026.json
# │   │   │   ├── 103-andromaca-safeBackup-0027.json
# │   │   │   ├── 103-andromaca-safeBackup-0028.json
# │   │   │   ├── 103-andromaca-safeBackup-0029.json
# │   │   │   ├── 103-andromaca-safeBackup-0030.json
# │   │   │   ├── 103-andromaca-safeBackup-0031.json
# │   │   │   ├── 103-andromaca-safeBackup-0032.json
# │   │   │   ├── 103-andromaca-safeBackup-0033.json
# │   │   │   ├── 103-andromaca-safeBackup-0034.json
# │   │   │   ├── 103-andromaca-safeBackup-0035.json
# │   │   │   ├── 103-andromaca-safeBackup-0036.json
# │   │   │   ├── 103-andromaca-safeBackup-0037.json
# │   │   │   ├── 103-andromaca-safeBackup-0038.json
# │   │   │   ├── 103-andromaca-safeBackup-0039.json
# │   │   │   ├── 103-andromaca-safeBackup-0040.json
# │   │   │   ├── 103-andromaca-safeBackup-0041.json
# │   │   │   ├── 103-andromaca-safeBackup-0042.json
# │   │   │   ├── 103-andromaca-safeBackup-0043.json
# │   │   │   ├── 103-andromaca-safeBackup-0044.json
# │   │   │   ├── 103-andromaca-safeBackup-0045.json
# │   │   │   ├── 103-andromaca-safeBackup-0046.json
# │   │   │   ├── 103-andromaca-safeBackup-0047.json
# │   │   │   ├── 103-andromaca-safeBackup-0048.json
# │   │   │   ├── 103-andromaca-safeBackup-0049.json
# │   │   │   ├── 103-andromaca-safeBackup-0050.json
# │   │   │   ├── 103-andromaca-safeBackup-0051.json
# │   │   │   ├── 103-andromaca-safeBackup-0052.json
# │   │   │   ├── 103-andromaca-safeBackup-0053.json
# │   │   │   ├── 103-andromaca-safeBackup-0054.json
# │   │   │   ├── 103-andromaca-safeBackup-0055.json
# │   │   │   ├── 103-andromaca-safeBackup-0056.json
# │   │   │   ├── 103-andromaca-safeBackup-0057.json
# │   │   │   ├── 103-andromaca-safeBackup-0058.json
# │   │   │   ├── 103-andromaca-safeBackup-0059.json
# │   │   │   ├── 103-andromaca-safeBackup-0060.json
# │   │   │   ├── 103-andromaca-safeBackup-0061.json
# │   │   │   ├── 103-andromaca-safeBackup-0062.json
# │   │   │   ├── 103-andromaca-safeBackup-0063.json
# │   │   │   ├── 103-andromaca-safeBackup-0064.json
# │   │   │   ├── 103-andromaca-safeBackup-0065.json
# │   │   │   ├── 103-andromaca-safeBackup-0066.json
# │   │   │   ├── 103-andromaca-safeBackup-0067.json
# │   │   │   ├── 103-andromaca-safeBackup-0068.json
# │   │   │   ├── 103-andromaca-safeBackup-0069.json
# │   │   │   ├── 103-andromaca-safeBackup-0070.json
# │   │   │   ├── 103-andromaca-safeBackup-0071.json
# │   │   │   ├── 103-andromaca-safeBackup-0072.json
# │   │   │   ├── 103-andromaca-safeBackup-0073.json
# │   │   │   ├── 103-andromaca-safeBackup-0074.json
# │   │   │   ├── 103-andromaca-safeBackup-0075.json
# │   │   │   ├── 103-andromaca-safeBackup-0076.json
# │   │   │   ├── 103-andromaca-safeBackup-0077.json
# │   │   │   ├── 103-andromaca-safeBackup-0078.json
# │   │   │   ├── 103-andromaca-safeBackup-0079.json
# │   │   │   ├── 103-andromaca-safeBackup-0080.json
# │   │   │   ├── 103-andromaca-safeBackup-0081.json
# │   │   │   ├── 103-andromaca-safeBackup-0082.json
# │   │   │   ├── 103-andromaca-safeBackup-0083.json
# │   │   │   ├── 103-andromaca-safeBackup-0084.json
# │   │   │   ├── 103-andromaca-safeBackup-0085.json
# │   │   │   ├── 103-andromaca-safeBackup-0086.json
# │   │   │   ├── 103-andromaca-safeBackup-0087.json
# │   │   │   ├── 103-andromaca-safeBackup-0088.json
# │   │   │   ├── 103-andromaca-safeBackup-0089.json
# │   │   │   ├── 103-andromaca-safeBackup-0090.json
# │   │   │   ├── 103-andromaca-safeBackup-0091.json
# │   │   │   ├── 103-andromaca-safeBackup-0092.json
# │   │   │   ├── 103-andromaca-safeBackup-0093.json
# │   │   │   ├── 103-andromaca-safeBackup-0094.json
# │   │   │   ├── 103-andromaca-safeBackup-0095.json
# │   │   │   ├── 103-andromaca-safeBackup-0096.json
# │   │   │   ├── 103-andromaca-safeBackup-0097.json
# │   │   │   ├── 103-andromaca-safeBackup-0098.json
# │   │   │   ├── 103-andromaca-safeBackup-0099.json
# │   │   │   ├── 103-andromaca-safeBackup-0100.json
# │   │   │   ├── 103-andromaca-safeBackup-0101.json
# │   │   │   ├── 103-andromaca-safeBackup-0102.json
# │   │   │   ├── 103-andromaca-safeBackup-0103.json
# │   │   │   ├── 103-andromaca-safeBackup-0104.json
# │   │   │   ├── 103-andromaca-safeBackup-0105.json
# │   │   │   ├── 103-andromaca-safeBackup-0106.json
# │   │   │   ├── 103-andromaca-safeBackup-0107.json
# │   │   │   ├── 103-andromaca-safeBackup-0108.json
# │   │   │   ├── 103-andromaca-safeBackup-0109.json
# │   │   │   ├── 103-andromaca-safeBackup-0110.json
# │   │   │   ├── 103-andromaca-safeBackup-0111.json
# │   │   │   ├── 103-andromaca-safeBackup-0112.json
# │   │   │   ├── 103-andromaca-safeBackup-0113.json
# │   │   │   ├── 103-andromaca-safeBackup-0114.json
# │   │   │   ├── 103-andromaca-safeBackup-0115.json
# │   │   │   ├── 103-andromaca-safeBackup-0116.json
# │   │   │   ├── 103-andromaca-safeBackup-0117.json
# │   │   │   ├── 103-andromaca-safeBackup-0118.json
# │   │   │   ├── 103-andromaca-safeBackup-0119.json
# │   │   │   ├── 103-andromaca-safeBackup-0120.json
# │   │   │   ├── 103-andromaca-safeBackup-0121.json
# │   │   │   ├── 103-andromaca-safeBackup-0122.json
# │   │   │   ├── 103-andromaca-safeBackup-0123.json
# │   │   │   ├── 103-andromaca-safeBackup-0124.json
# │   │   │   ├── 103-andromaca-safeBackup-0125.json
# │   │   │   ├── 103-PC-Miguel-10.json
# │   │   │   ├── 103-PC-Miguel-11.json
# │   │   │   ├── 103-PC-Miguel-12.json
# │   │   │   ├── 103-PC-Miguel-13.json
# │   │   │   ├── 103-PC-Miguel-14.json
# │   │   │   ├── 103-PC-Miguel-15.json
# │   │   │   ├── 103-PC-Miguel-2.json
# │   │   │   ├── 103-PC-Miguel-3.json
# │   │   │   ├── 103-PC-Miguel-4.json
# │   │   │   ├── 103-PC-Miguel-5.json
# │   │   │   ├── 103-PC-Miguel-6.json
# │   │   │   ├── 103-PC-Miguel-7.json
# │   │   │   ├── 103-PC-Miguel-8.json
# │   │   │   ├── 103-PC-Miguel-9.json
# │   │   │   ├── 103-PC-Miguel.json
# │   │   │   ├── 103.json
# │   │   │   ├── 104-andromaca-safeBackup-0001.json
# │   │   │   ├── 104-andromaca-safeBackup-0002.json
# │   │   │   ├── 104-andromaca-safeBackup-0003.json
# │   │   │   ├── 104-andromaca-safeBackup-0004.json
# │   │   │   ├── 104-andromaca-safeBackup-0005.json
# │   │   │   ├── 104-andromaca-safeBackup-0006.json
# │   │   │   ├── 104-andromaca-safeBackup-0007.json
# │   │   │   ├── 104-andromaca-safeBackup-0008.json
# │   │   │   ├── 104-andromaca-safeBackup-0009.json
# │   │   │   ├── 104-andromaca-safeBackup-0010.json
# │   │   │   ├── 104-andromaca-safeBackup-0011.json
# │   │   │   ├── 104-andromaca-safeBackup-0012.json
# │   │   │   ├── 104-andromaca-safeBackup-0013.json
# │   │   │   ├── 104-andromaca-safeBackup-0014.json
# │   │   │   ├── 104-andromaca-safeBackup-0015.json
# │   │   │   ├── 104-andromaca-safeBackup-0016.json
# │   │   │   ├── 104-andromaca-safeBackup-0017.json
# │   │   │   ├── 104-andromaca-safeBackup-0018.json
# │   │   │   ├── 104-andromaca-safeBackup-0019.json
# │   │   │   ├── 104-andromaca-safeBackup-0020.json
# │   │   │   ├── 104-andromaca-safeBackup-0021.json
# │   │   │   ├── 104-andromaca-safeBackup-0022.json
# │   │   │   ├── 104-andromaca-safeBackup-0023.json
# │   │   │   ├── 104-andromaca-safeBackup-0024.json
# │   │   │   ├── 104-andromaca-safeBackup-0025.json
# │   │   │   ├── 104-andromaca-safeBackup-0026.json
# │   │   │   ├── 104-andromaca-safeBackup-0027.json
# │   │   │   ├── 104-andromaca-safeBackup-0028.json
# │   │   │   ├── 104-andromaca-safeBackup-0029.json
# │   │   │   ├── 104-andromaca-safeBackup-0030.json
# │   │   │   ├── 104-andromaca-safeBackup-0031.json
# │   │   │   ├── 104-andromaca-safeBackup-0032.json
# │   │   │   ├── 104-andromaca-safeBackup-0033.json
# │   │   │   ├── 104-andromaca-safeBackup-0034.json
# │   │   │   ├── 104-andromaca-safeBackup-0035.json
# │   │   │   ├── 104-andromaca-safeBackup-0036.json
# │   │   │   ├── 104-andromaca-safeBackup-0037.json
# │   │   │   ├── 104-andromaca-safeBackup-0038.json
# │   │   │   ├── 104-andromaca-safeBackup-0039.json
# │   │   │   ├── 104-andromaca-safeBackup-0040.json
# │   │   │   ├── 104-andromaca-safeBackup-0041.json
# │   │   │   ├── 104-andromaca-safeBackup-0042.json
# │   │   │   ├── 104-andromaca-safeBackup-0043.json
# │   │   │   ├── 104-andromaca-safeBackup-0044.json
# │   │   │   ├── 104-andromaca-safeBackup-0045.json
# │   │   │   ├── 104-andromaca-safeBackup-0046.json
# │   │   │   ├── 104-andromaca-safeBackup-0047.json
# │   │   │   ├── 104-andromaca-safeBackup-0048.json
# │   │   │   ├── 104-andromaca-safeBackup-0049.json
# │   │   │   ├── 104-andromaca-safeBackup-0050.json
# │   │   │   ├── 104-andromaca-safeBackup-0051.json
# │   │   │   ├── 104-andromaca-safeBackup-0052.json
# │   │   │   ├── 104-andromaca-safeBackup-0053.json
# │   │   │   ├── 104-andromaca-safeBackup-0054.json
# │   │   │   ├── 104-andromaca-safeBackup-0055.json
# │   │   │   ├── 104-andromaca-safeBackup-0056.json
# │   │   │   ├── 104-andromaca-safeBackup-0057.json
# │   │   │   ├── 104-andromaca-safeBackup-0058.json
# │   │   │   ├── 104-andromaca-safeBackup-0059.json
# │   │   │   ├── 104-andromaca-safeBackup-0060.json
# │   │   │   ├── 104-andromaca-safeBackup-0061.json
# │   │   │   ├── 104-andromaca-safeBackup-0062.json
# │   │   │   ├── 104-andromaca-safeBackup-0063.json
# │   │   │   ├── 104-andromaca-safeBackup-0064.json
# │   │   │   ├── 104-andromaca-safeBackup-0065.json
# │   │   │   ├── 104-andromaca-safeBackup-0066.json
# │   │   │   ├── 104-andromaca-safeBackup-0067.json
# │   │   │   ├── 104-andromaca-safeBackup-0068.json
# │   │   │   ├── 104-andromaca-safeBackup-0069.json
# │   │   │   ├── 104-andromaca-safeBackup-0070.json
# │   │   │   ├── 104-andromaca-safeBackup-0071.json
# │   │   │   ├── 104-andromaca-safeBackup-0072.json
# │   │   │   ├── 104-andromaca-safeBackup-0073.json
# │   │   │   ├── 104-andromaca-safeBackup-0074.json
# │   │   │   ├── 104-andromaca-safeBackup-0075.json
# │   │   │   ├── 104-andromaca-safeBackup-0076.json
# │   │   │   ├── 104-andromaca-safeBackup-0077.json
# │   │   │   ├── 104-andromaca-safeBackup-0078.json
# │   │   │   ├── 104-andromaca-safeBackup-0079.json
# │   │   │   ├── 104-andromaca-safeBackup-0080.json
# │   │   │   ├── 104-andromaca-safeBackup-0081.json
# │   │   │   ├── 104-andromaca-safeBackup-0082.json
# │   │   │   ├── 104-andromaca-safeBackup-0083.json
# │   │   │   ├── 104-andromaca-safeBackup-0084.json
# │   │   │   ├── 104-andromaca-safeBackup-0085.json
# │   │   │   ├── 104-andromaca-safeBackup-0086.json
# │   │   │   ├── 104-andromaca-safeBackup-0087.json
# │   │   │   ├── 104-andromaca-safeBackup-0088.json
# │   │   │   ├── 104-andromaca-safeBackup-0089.json
# │   │   │   ├── 104-andromaca-safeBackup-0090.json
# │   │   │   ├── 104-andromaca-safeBackup-0091.json
# │   │   │   ├── 104-andromaca-safeBackup-0092.json
# │   │   │   ├── 104-andromaca-safeBackup-0093.json
# │   │   │   ├── 104-andromaca-safeBackup-0094.json
# │   │   │   ├── 104-andromaca-safeBackup-0095.json
# │   │   │   ├── 104-andromaca-safeBackup-0096.json
# │   │   │   ├── 104-andromaca-safeBackup-0097.json
# │   │   │   ├── 104-andromaca-safeBackup-0098.json
# │   │   │   ├── 104-andromaca-safeBackup-0099.json
# │   │   │   ├── 104-andromaca-safeBackup-0100.json
# │   │   │   ├── 104-andromaca-safeBackup-0101.json
# │   │   │   ├── 104-andromaca-safeBackup-0102.json
# │   │   │   ├── 104-andromaca-safeBackup-0103.json
# │   │   │   ├── 104-andromaca-safeBackup-0104.json
# │   │   │   ├── 104-andromaca-safeBackup-0105.json
# │   │   │   ├── 104-andromaca-safeBackup-0106.json
# │   │   │   ├── 104-andromaca-safeBackup-0107.json
# │   │   │   ├── 104-andromaca-safeBackup-0108.json
# │   │   │   ├── 104-andromaca-safeBackup-0109.json
# │   │   │   ├── 104-andromaca-safeBackup-0110.json
# │   │   │   ├── 104-andromaca-safeBackup-0111.json
# │   │   │   ├── 104-andromaca-safeBackup-0112.json
# │   │   │   ├── 104-andromaca-safeBackup-0113.json
# │   │   │   ├── 104-andromaca-safeBackup-0114.json
# │   │   │   ├── 104-andromaca-safeBackup-0115.json
# │   │   │   ├── 104-andromaca-safeBackup-0116.json
# │   │   │   ├── 104-andromaca-safeBackup-0117.json
# │   │   │   ├── 104-andromaca-safeBackup-0118.json
# │   │   │   ├── 104-andromaca-safeBackup-0119.json
# │   │   │   ├── 104-andromaca-safeBackup-0120.json
# │   │   │   ├── 104-andromaca-safeBackup-0121.json
# │   │   │   ├── 104-andromaca-safeBackup-0122.json
# │   │   │   ├── 104-andromaca-safeBackup-0123.json
# │   │   │   ├── 104-andromaca-safeBackup-0124.json
# │   │   │   ├── 104-andromaca-safeBackup-0125.json
# │   │   │   ├── 104-andromaca-safeBackup-0126.json
# │   │   │   ├── 104-andromaca-safeBackup-0127.json
# │   │   │   ├── 104-andromaca-safeBackup-0128.json
# │   │   │   ├── 104-andromaca-safeBackup-0129.json
# │   │   │   ├── 104-andromaca-safeBackup-0130.json
# │   │   │   ├── 104-andromaca-safeBackup-0131.json
# │   │   │   ├── 104-andromaca-safeBackup-0132.json
# │   │   │   ├── 104-PC-Miguel-10.json
# │   │   │   ├── 104-PC-Miguel-2.json
# │   │   │   ├── 104-PC-Miguel-3.json
# │   │   │   ├── 104-PC-Miguel-4.json
# │   │   │   ├── 104-PC-Miguel-5.json
# │   │   │   ├── 104-PC-Miguel-6.json
# │   │   │   ├── 104-PC-Miguel-7.json
# │   │   │   ├── 104-PC-Miguel-8.json
# │   │   │   ├── 104-PC-Miguel-9.json
# │   │   │   ├── 104-PC-Miguel.json
# │   │   │   ├── 104.json
# │   │   │   ├── 105-andromaca-safeBackup-0001.json
# │   │   │   ├── 105-andromaca-safeBackup-0002.json
# │   │   │   ├── 105-andromaca-safeBackup-0003.json
# │   │   │   ├── 105-andromaca-safeBackup-0004.json
# │   │   │   ├── 105-andromaca-safeBackup-0005.json
# │   │   │   ├── 105-andromaca-safeBackup-0006.json
# │   │   │   ├── 105-andromaca-safeBackup-0007.json
# │   │   │   ├── 105-andromaca-safeBackup-0008.json
# │   │   │   ├── 105-andromaca-safeBackup-0009.json
# │   │   │   ├── 105-andromaca-safeBackup-0010.json
# │   │   │   ├── 105-andromaca-safeBackup-0011.json
# │   │   │   ├── 105-andromaca-safeBackup-0012.json
# │   │   │   ├── 105-andromaca-safeBackup-0013.json
# │   │   │   ├── 105-andromaca-safeBackup-0014.json
# │   │   │   ├── 105-andromaca-safeBackup-0015.json
# │   │   │   ├── 105-andromaca-safeBackup-0016.json
# │   │   │   ├── 105-andromaca-safeBackup-0017.json
# │   │   │   ├── 105-andromaca-safeBackup-0018.json
# │   │   │   ├── 105-andromaca-safeBackup-0019.json
# │   │   │   ├── 105-andromaca-safeBackup-0020.json
# │   │   │   ├── 105-andromaca-safeBackup-0021.json
# │   │   │   ├── 105-andromaca-safeBackup-0022.json
# │   │   │   ├── 105-andromaca-safeBackup-0023.json
# │   │   │   ├── 105-andromaca-safeBackup-0024.json
# │   │   │   ├── 105-andromaca-safeBackup-0025.json
# │   │   │   ├── 105-andromaca-safeBackup-0026.json
# │   │   │   ├── 105-andromaca-safeBackup-0027.json
# │   │   │   ├── 105-andromaca-safeBackup-0028.json
# │   │   │   ├── 105-andromaca-safeBackup-0029.json
# │   │   │   ├── 105-andromaca-safeBackup-0030.json
# │   │   │   ├── 105-andromaca-safeBackup-0031.json
# │   │   │   ├── 105-andromaca-safeBackup-0032.json
# │   │   │   ├── 105-andromaca-safeBackup-0033.json
# │   │   │   ├── 105-andromaca-safeBackup-0034.json
# │   │   │   ├── 105-andromaca-safeBackup-0035.json
# │   │   │   ├── 105-andromaca-safeBackup-0036.json
# │   │   │   ├── 105-andromaca-safeBackup-0037.json
# │   │   │   ├── 105-andromaca-safeBackup-0038.json
# │   │   │   ├── 105-andromaca-safeBackup-0039.json
# │   │   │   ├── 105-andromaca-safeBackup-0040.json
# │   │   │   ├── 105-andromaca-safeBackup-0041.json
# │   │   │   ├── 105-andromaca-safeBackup-0042.json
# │   │   │   ├── 105-andromaca-safeBackup-0043.json
# │   │   │   ├── 105-andromaca-safeBackup-0044.json
# │   │   │   ├── 105-andromaca-safeBackup-0045.json
# │   │   │   ├── 105-andromaca-safeBackup-0046.json
# │   │   │   ├── 105-andromaca-safeBackup-0047.json
# │   │   │   ├── 105-andromaca-safeBackup-0048.json
# │   │   │   ├── 105-andromaca-safeBackup-0049.json
# │   │   │   ├── 105-andromaca-safeBackup-0050.json
# │   │   │   ├── 105-andromaca-safeBackup-0051.json
# │   │   │   ├── 105-andromaca-safeBackup-0052.json
# │   │   │   ├── 105-andromaca-safeBackup-0053.json
# │   │   │   ├── 105-andromaca-safeBackup-0054.json
# │   │   │   ├── 105-andromaca-safeBackup-0055.json
# │   │   │   ├── 105-andromaca-safeBackup-0056.json
# │   │   │   ├── 105-andromaca-safeBackup-0057.json
# │   │   │   ├── 105-andromaca-safeBackup-0058.json
# │   │   │   ├── 105-andromaca-safeBackup-0059.json
# │   │   │   ├── 105-andromaca-safeBackup-0060.json
# │   │   │   ├── 105-andromaca-safeBackup-0061.json
# │   │   │   ├── 105-andromaca-safeBackup-0062.json
# │   │   │   ├── 105-andromaca-safeBackup-0063.json
# │   │   │   ├── 105-andromaca-safeBackup-0064.json
# │   │   │   ├── 105-andromaca-safeBackup-0065.json
# │   │   │   ├── 105-andromaca-safeBackup-0066.json
# │   │   │   ├── 105-andromaca-safeBackup-0067.json
# │   │   │   ├── 105-andromaca-safeBackup-0068.json
# │   │   │   ├── 105-andromaca-safeBackup-0069.json
# │   │   │   ├── 105-andromaca-safeBackup-0070.json
# │   │   │   ├── 105-andromaca-safeBackup-0071.json
# │   │   │   ├── 105-andromaca-safeBackup-0072.json
# │   │   │   ├── 105-andromaca-safeBackup-0073.json
# │   │   │   ├── 105-andromaca-safeBackup-0074.json
# │   │   │   ├── 105-andromaca-safeBackup-0075.json
# │   │   │   ├── 105-andromaca-safeBackup-0076.json
# │   │   │   ├── 105-andromaca-safeBackup-0077.json
# │   │   │   ├── 105-andromaca-safeBackup-0078.json
# │   │   │   ├── 105-andromaca-safeBackup-0079.json
# │   │   │   ├── 105-andromaca-safeBackup-0080.json
# │   │   │   ├── 105-andromaca-safeBackup-0081.json
# │   │   │   ├── 105-andromaca-safeBackup-0082.json
# │   │   │   ├── 105-andromaca-safeBackup-0083.json
# │   │   │   ├── 105-andromaca-safeBackup-0084.json
# │   │   │   ├── 105-andromaca-safeBackup-0085.json
# │   │   │   ├── 105-andromaca-safeBackup-0086.json
# │   │   │   ├── 105-andromaca-safeBackup-0087.json
# │   │   │   ├── 105-andromaca-safeBackup-0088.json
# │   │   │   ├── 105-andromaca-safeBackup-0089.json
# │   │   │   ├── 105-andromaca-safeBackup-0090.json
# │   │   │   ├── 105-andromaca-safeBackup-0091.json
# │   │   │   ├── 105-andromaca-safeBackup-0092.json
# │   │   │   ├── 105-andromaca-safeBackup-0093.json
# │   │   │   ├── 105-andromaca-safeBackup-0094.json
# │   │   │   ├── 105-andromaca-safeBackup-0095.json
# │   │   │   ├── 105-andromaca-safeBackup-0096.json
# │   │   │   ├── 105-andromaca-safeBackup-0097.json
# │   │   │   ├── 105-andromaca-safeBackup-0098.json
# │   │   │   ├── 105-andromaca-safeBackup-0099.json
# │   │   │   ├── 105-PC-Miguel-2.json
# │   │   │   ├── 105-PC-Miguel.json
# │   │   │   ├── 105.json
# │   │   │   ├── 300-andromaca-safeBackup-0001.json
# │   │   │   ├── 300-andromaca-safeBackup-0002.json
# │   │   │   ├── 300-andromaca-safeBackup-0003.json
# │   │   │   ├── 300-andromaca-safeBackup-0004.json
# │   │   │   ├── 300-andromaca-safeBackup-0005.json
# │   │   │   ├── 300-andromaca-safeBackup-0006.json
# │   │   │   ├── 300-andromaca-safeBackup-0007.json
# │   │   │   ├── 300-andromaca-safeBackup-0008.json
# │   │   │   ├── 300-andromaca-safeBackup-0009.json
# │   │   │   ├── 300-andromaca-safeBackup-0010.json
# │   │   │   ├── 300-andromaca-safeBackup-0011.json
# │   │   │   ├── 300-andromaca-safeBackup-0012.json
# │   │   │   ├── 300-andromaca-safeBackup-0013.json
# │   │   │   ├── 300-andromaca-safeBackup-0014.json
# │   │   │   ├── 300-andromaca-safeBackup-0015.json
# │   │   │   ├── 300-andromaca-safeBackup-0016.json
# │   │   │   ├── 300-andromaca-safeBackup-0017.json
# │   │   │   ├── 300-andromaca-safeBackup-0018.json
# │   │   │   ├── 300-andromaca-safeBackup-0019.json
# │   │   │   ├── 300-andromaca-safeBackup-0020.json
# │   │   │   ├── 300-andromaca-safeBackup-0021.json
# │   │   │   ├── 300-andromaca-safeBackup-0022.json
# │   │   │   ├── 300-andromaca-safeBackup-0023.json
# │   │   │   ├── 300-andromaca-safeBackup-0024.json
# │   │   │   ├── 300-andromaca-safeBackup-0025.json
# │   │   │   ├── 300-andromaca-safeBackup-0026.json
# │   │   │   ├── 300-andromaca-safeBackup-0027.json
# │   │   │   ├── 300-andromaca-safeBackup-0028.json
# │   │   │   ├── 300-andromaca-safeBackup-0029.json
# │   │   │   ├── 300-andromaca-safeBackup-0030.json
# │   │   │   ├── 300-andromaca-safeBackup-0031.json
# │   │   │   ├── 300-andromaca-safeBackup-0032.json
# │   │   │   ├── 300-andromaca-safeBackup-0033.json
# │   │   │   ├── 300-andromaca-safeBackup-0034.json
# │   │   │   ├── 300-andromaca-safeBackup-0035.json
# │   │   │   ├── 300-andromaca-safeBackup-0036.json
# │   │   │   ├── 300-andromaca-safeBackup-0037.json
# │   │   │   ├── 300-andromaca-safeBackup-0038.json
# │   │   │   ├── 300-andromaca-safeBackup-0039.json
# │   │   │   ├── 300-andromaca-safeBackup-0040.json
# │   │   │   ├── 300-andromaca-safeBackup-0041.json
# │   │   │   ├── 300-andromaca-safeBackup-0042.json
# │   │   │   ├── 300-andromaca-safeBackup-0043.json
# │   │   │   ├── 300-andromaca-safeBackup-0044.json
# │   │   │   ├── 300-andromaca-safeBackup-0045.json
# │   │   │   ├── 300-andromaca-safeBackup-0046.json
# │   │   │   ├── 300-andromaca-safeBackup-0047.json
# │   │   │   ├── 300-andromaca-safeBackup-0048.json
# │   │   │   ├── 300-andromaca-safeBackup-0049.json
# │   │   │   ├── 300-andromaca-safeBackup-0050.json
# │   │   │   ├── 300-andromaca-safeBackup-0051.json
# │   │   │   ├── 300-andromaca-safeBackup-0052.json
# │   │   │   ├── 300-andromaca-safeBackup-0053.json
# │   │   │   ├── 300-andromaca-safeBackup-0054.json
# │   │   │   ├── 300-andromaca-safeBackup-0055.json
# │   │   │   ├── 300-andromaca-safeBackup-0056.json
# │   │   │   ├── 300-andromaca-safeBackup-0057.json
# │   │   │   ├── 300-andromaca-safeBackup-0058.json
# │   │   │   ├── 300-andromaca-safeBackup-0059.json
# │   │   │   ├── 300-andromaca-safeBackup-0060.json
# │   │   │   ├── 300-andromaca-safeBackup-0061.json
# │   │   │   ├── 300-andromaca-safeBackup-0062.json
# │   │   │   ├── 300-andromaca-safeBackup-0063.json
# │   │   │   ├── 300-andromaca-safeBackup-0064.json
# │   │   │   ├── 300-andromaca-safeBackup-0065.json
# │   │   │   ├── 300-andromaca-safeBackup-0066.json
# │   │   │   ├── 300-andromaca-safeBackup-0067.json
# │   │   │   ├── 300-andromaca-safeBackup-0068.json
# │   │   │   ├── 300-andromaca-safeBackup-0069.json
# │   │   │   ├── 300-andromaca-safeBackup-0070.json
# │   │   │   ├── 300-andromaca-safeBackup-0071.json
# │   │   │   ├── 300-andromaca-safeBackup-0072.json
# │   │   │   ├── 300-andromaca-safeBackup-0073.json
# │   │   │   ├── 300-andromaca-safeBackup-0074.json
# │   │   │   ├── 300-andromaca-safeBackup-0075.json
# │   │   │   ├── 300-andromaca-safeBackup-0076.json
# │   │   │   ├── 300-andromaca-safeBackup-0077.json
# │   │   │   ├── 300-andromaca-safeBackup-0078.json
# │   │   │   ├── 300-andromaca-safeBackup-0079.json
# │   │   │   ├── 300-andromaca-safeBackup-0080.json
# │   │   │   ├── 300-andromaca-safeBackup-0081.json
# │   │   │   ├── 300-andromaca-safeBackup-0082.json
# │   │   │   ├── 300-andromaca-safeBackup-0083.json
# │   │   │   ├── 300-andromaca-safeBackup-0084.json
# │   │   │   ├── 300-andromaca-safeBackup-0085.json
# │   │   │   ├── 300-andromaca-safeBackup-0086.json
# │   │   │   ├── 300-andromaca-safeBackup-0087.json
# │   │   │   ├── 300-andromaca-safeBackup-0088.json
# │   │   │   ├── 300-andromaca-safeBackup-0089.json
# │   │   │   ├── 300-andromaca-safeBackup-0090.json
# │   │   │   ├── 300-PC-Miguel.json
# │   │   │   ├── 300.json
# │   │   │   ├── 302-andromaca-safeBackup-0001.json
# │   │   │   ├── 302-andromaca-safeBackup-0002.json
# │   │   │   ├── 302-andromaca-safeBackup-0003.json
# │   │   │   ├── 302-andromaca-safeBackup-0004.json
# │   │   │   ├── 302-andromaca-safeBackup-0005.json
# │   │   │   ├── 302-andromaca-safeBackup-0006.json
# │   │   │   ├── 302-andromaca-safeBackup-0007.json
# │   │   │   ├── 302-andromaca-safeBackup-0008.json
# │   │   │   ├── 302-andromaca-safeBackup-0009.json
# │   │   │   ├── 302-andromaca-safeBackup-0010.json
# │   │   │   ├── 302-andromaca-safeBackup-0011.json
# │   │   │   ├── 302-andromaca-safeBackup-0012.json
# │   │   │   ├── 302-andromaca-safeBackup-0013.json
# │   │   │   ├── 302-andromaca-safeBackup-0014.json
# │   │   │   ├── 302-andromaca-safeBackup-0015.json
# │   │   │   ├── 302-andromaca-safeBackup-0016.json
# │   │   │   ├── 302-andromaca-safeBackup-0017.json
# │   │   │   ├── 302-andromaca-safeBackup-0018.json
# │   │   │   ├── 302-andromaca-safeBackup-0019.json
# │   │   │   ├── 302-andromaca-safeBackup-0020.json
# │   │   │   ├── 302-andromaca-safeBackup-0021.json
# │   │   │   ├── 302-andromaca-safeBackup-0022.json
# │   │   │   ├── 302-andromaca-safeBackup-0023.json
# │   │   │   ├── 302-andromaca-safeBackup-0024.json
# │   │   │   ├── 302-andromaca-safeBackup-0025.json
# │   │   │   ├── 302-andromaca-safeBackup-0026.json
# │   │   │   ├── 302-andromaca-safeBackup-0027.json
# │   │   │   ├── 302-andromaca-safeBackup-0028.json
# │   │   │   ├── 302-andromaca-safeBackup-0029.json
# │   │   │   ├── 302-andromaca-safeBackup-0030.json
# │   │   │   ├── 302-andromaca-safeBackup-0031.json
# │   │   │   ├── 302-andromaca-safeBackup-0032.json
# │   │   │   ├── 302-andromaca-safeBackup-0033.json
# │   │   │   ├── 302-andromaca-safeBackup-0034.json
# │   │   │   ├── 302-andromaca-safeBackup-0035.json
# │   │   │   ├── 302-andromaca-safeBackup-0036.json
# │   │   │   ├── 302-andromaca-safeBackup-0037.json
# │   │   │   ├── 302-andromaca-safeBackup-0038.json
# │   │   │   ├── 302-andromaca-safeBackup-0039.json
# │   │   │   ├── 302-andromaca-safeBackup-0040.json
# │   │   │   ├── 302-andromaca-safeBackup-0041.json
# │   │   │   ├── 302-andromaca-safeBackup-0042.json
# │   │   │   ├── 302-andromaca-safeBackup-0043.json
# │   │   │   ├── 302-andromaca-safeBackup-0044.json
# │   │   │   ├── 302-andromaca-safeBackup-0045.json
# │   │   │   ├── 302-andromaca-safeBackup-0046.json
# │   │   │   ├── 302-andromaca-safeBackup-0047.json
# │   │   │   ├── 302-andromaca-safeBackup-0048.json
# │   │   │   ├── 302-andromaca-safeBackup-0049.json
# │   │   │   ├── 302-andromaca-safeBackup-0050.json
# │   │   │   ├── 302-andromaca-safeBackup-0051.json
# │   │   │   ├── 302-andromaca-safeBackup-0052.json
# │   │   │   ├── 302-andromaca-safeBackup-0053.json
# │   │   │   ├── 302-andromaca-safeBackup-0054.json
# │   │   │   ├── 302-andromaca-safeBackup-0055.json
# │   │   │   ├── 302-andromaca-safeBackup-0056.json
# │   │   │   ├── 302-andromaca-safeBackup-0057.json
# │   │   │   ├── 302-andromaca-safeBackup-0058.json
# │   │   │   ├── 302-andromaca-safeBackup-0059.json
# │   │   │   ├── 302-andromaca-safeBackup-0060.json
# │   │   │   ├── 302-andromaca-safeBackup-0061.json
# │   │   │   ├── 302-andromaca-safeBackup-0062.json
# │   │   │   ├── 302-andromaca-safeBackup-0063.json
# │   │   │   ├── 302-andromaca-safeBackup-0064.json
# │   │   │   ├── 302-andromaca-safeBackup-0065.json
# │   │   │   ├── 302-andromaca-safeBackup-0066.json
# │   │   │   ├── 302-andromaca-safeBackup-0067.json
# │   │   │   ├── 302-andromaca-safeBackup-0068.json
# │   │   │   ├── 302-andromaca-safeBackup-0069.json
# │   │   │   ├── 302-andromaca-safeBackup-0070.json
# │   │   │   ├── 302-andromaca-safeBackup-0071.json
# │   │   │   ├── 302-andromaca-safeBackup-0072.json
# │   │   │   ├── 302-andromaca-safeBackup-0073.json
# │   │   │   ├── 302-andromaca-safeBackup-0074.json
# │   │   │   ├── 302-andromaca-safeBackup-0075.json
# │   │   │   ├── 302-andromaca-safeBackup-0076.json
# │   │   │   ├── 302-andromaca-safeBackup-0077.json
# │   │   │   ├── 302-andromaca-safeBackup-0078.json
# │   │   │   ├── 302-andromaca-safeBackup-0079.json
# │   │   │   ├── 302-andromaca-safeBackup-0080.json
# │   │   │   ├── 302-andromaca-safeBackup-0081.json
# │   │   │   ├── 302-andromaca-safeBackup-0082.json
# │   │   │   ├── 302-andromaca-safeBackup-0083.json
# │   │   │   ├── 302-andromaca-safeBackup-0084.json
# │   │   │   ├── 302-andromaca-safeBackup-0085.json
# │   │   │   ├── 302-andromaca-safeBackup-0086.json
# │   │   │   ├── 302-andromaca-safeBackup-0087.json
# │   │   │   ├── 302-andromaca-safeBackup-0088.json
# │   │   │   ├── 302-andromaca-safeBackup-0089.json
# │   │   │   ├── 302-andromaca-safeBackup-0090.json
# │   │   │   ├── 302-andromaca-safeBackup-0091.json
# │   │   │   ├── 302-andromaca-safeBackup-0092.json
# │   │   │   ├── 302-andromaca-safeBackup-0093.json
# │   │   │   ├── 302-andromaca-safeBackup-0094.json
# │   │   │   ├── 302-PC-Miguel-2.json
# │   │   │   ├── 302-PC-Miguel-3.json
# │   │   │   ├── 302-PC-Miguel-4.json
# │   │   │   ├── 302-PC-Miguel-5.json
# │   │   │   ├── 302-PC-Miguel.json
# │   │   │   ├── 302.json
# │   │   │   ├── 320.json
# │   │   │   ├── 321-1.json
# │   │   │   ├── 321.json
# │   │   │   ├── 322.json
# │   │   │   ├── 323.json
# │   │   │   ├── 701-andromaca-safeBackup-0001.json
# │   │   │   ├── 701-andromaca-safeBackup-0002.json
# │   │   │   ├── 701-andromaca-safeBackup-0003.json
# │   │   │   ├── 701-andromaca-safeBackup-0004.json
# │   │   │   ├── 701-andromaca-safeBackup-0005.json
# │   │   │   ├── 701-andromaca-safeBackup-0006.json
# │   │   │   ├── 701-andromaca-safeBackup-0007.json
# │   │   │   ├── 701-andromaca-safeBackup-0008.json
# │   │   │   ├── 701-andromaca-safeBackup-0009.json
# │   │   │   ├── 701-andromaca-safeBackup-0010.json
# │   │   │   ├── 701-andromaca-safeBackup-0011.json
# │   │   │   ├── 701-andromaca-safeBackup-0012.json
# │   │   │   ├── 701-andromaca-safeBackup-0013.json
# │   │   │   ├── 701-andromaca-safeBackup-0014.json
# │   │   │   ├── 701-andromaca-safeBackup-0015.json
# │   │   │   ├── 701-andromaca-safeBackup-0016.json
# │   │   │   ├── 701-andromaca-safeBackup-0017.json
# │   │   │   ├── 701-andromaca-safeBackup-0018.json
# │   │   │   ├── 701-andromaca-safeBackup-0019.json
# │   │   │   ├── 701-andromaca-safeBackup-0020.json
# │   │   │   ├── 701-andromaca-safeBackup-0021.json
# │   │   │   ├── 701-andromaca-safeBackup-0022.json
# │   │   │   ├── 701-andromaca-safeBackup-0023.json
# │   │   │   ├── 701-andromaca-safeBackup-0024.json
# │   │   │   ├── 701-andromaca-safeBackup-0025.json
# │   │   │   ├── 701-andromaca-safeBackup-0026.json
# │   │   │   ├── 701-andromaca-safeBackup-0027.json
# │   │   │   ├── 701-andromaca-safeBackup-0028.json
# │   │   │   ├── 701-andromaca-safeBackup-0029.json
# │   │   │   ├── 701-andromaca-safeBackup-0030.json
# │   │   │   ├── 701-andromaca-safeBackup-0031.json
# │   │   │   ├── 701-andromaca-safeBackup-0032.json
# │   │   │   ├── 701-andromaca-safeBackup-0033.json
# │   │   │   ├── 701-andromaca-safeBackup-0034.json
# │   │   │   ├── 701-andromaca-safeBackup-0035.json
# │   │   │   ├── 701-andromaca-safeBackup-0036.json
# │   │   │   ├── 701-andromaca-safeBackup-0037.json
# │   │   │   ├── 701-andromaca-safeBackup-0038.json
# │   │   │   ├── 701-andromaca-safeBackup-0039.json
# │   │   │   ├── 701-andromaca-safeBackup-0040.json
# │   │   │   ├── 701-andromaca-safeBackup-0041.json
# │   │   │   ├── 701-andromaca-safeBackup-0042.json
# │   │   │   ├── 701-andromaca-safeBackup-0043.json
# │   │   │   ├── 701-andromaca-safeBackup-0044.json
# │   │   │   ├── 701-andromaca-safeBackup-0045.json
# │   │   │   ├── 701-andromaca-safeBackup-0046.json
# │   │   │   ├── 701-andromaca-safeBackup-0047.json
# │   │   │   ├── 701-andromaca-safeBackup-0048.json
# │   │   │   ├── 701-andromaca-safeBackup-0049.json
# │   │   │   ├── 701-andromaca-safeBackup-0050.json
# │   │   │   ├── 701-andromaca-safeBackup-0051.json
# │   │   │   ├── 701-andromaca-safeBackup-0052.json
# │   │   │   ├── 701-andromaca-safeBackup-0053.json
# │   │   │   ├── 701-andromaca-safeBackup-0054.json
# │   │   │   ├── 701-andromaca-safeBackup-0055.json
# │   │   │   ├── 701-andromaca-safeBackup-0056.json
# │   │   │   ├── 701-andromaca-safeBackup-0057.json
# │   │   │   ├── 701-andromaca-safeBackup-0058.json
# │   │   │   ├── 701-andromaca-safeBackup-0059.json
# │   │   │   ├── 701-andromaca-safeBackup-0060.json
# │   │   │   ├── 701-andromaca-safeBackup-0061.json
# │   │   │   ├── 701-andromaca-safeBackup-0062.json
# │   │   │   ├── 701-andromaca-safeBackup-0063.json
# │   │   │   ├── 701-andromaca-safeBackup-0064.json
# │   │   │   ├── 701-andromaca-safeBackup-0065.json
# │   │   │   ├── 701-andromaca-safeBackup-0066.json
# │   │   │   ├── 701-andromaca-safeBackup-0067.json
# │   │   │   ├── 701-andromaca-safeBackup-0068.json
# │   │   │   ├── 701-andromaca-safeBackup-0069.json
# │   │   │   ├── 701-andromaca-safeBackup-0070.json
# │   │   │   ├── 701-andromaca-safeBackup-0071.json
# │   │   │   ├── 701-andromaca-safeBackup-0072.json
# │   │   │   ├── 701-andromaca-safeBackup-0073.json
# │   │   │   ├── 701-andromaca-safeBackup-0074.json
# │   │   │   ├── 701-andromaca-safeBackup-0075.json
# │   │   │   ├── 701-andromaca-safeBackup-0076.json
# │   │   │   ├── 701-andromaca-safeBackup-0077.json
# │   │   │   ├── 701-andromaca-safeBackup-0078.json
# │   │   │   ├── 701-andromaca-safeBackup-0079.json
# │   │   │   ├── 701-andromaca-safeBackup-0080.json
# │   │   │   ├── 701-andromaca-safeBackup-0081.json
# │   │   │   ├── 701-andromaca-safeBackup-0082.json
# │   │   │   ├── 701-andromaca-safeBackup-0083.json
# │   │   │   ├── 701-andromaca-safeBackup-0084.json
# │   │   │   ├── 701-andromaca-safeBackup-0085.json
# │   │   │   ├── 701-andromaca-safeBackup-0086.json
# │   │   │   ├── 701-andromaca-safeBackup-0087.json
# │   │   │   ├── 701-andromaca-safeBackup-0088.json
# │   │   │   ├── 701-andromaca-safeBackup-0089.json
# │   │   │   ├── 701-andromaca-safeBackup-0090.json
# │   │   │   ├── 701-andromaca-safeBackup-0091.json
# │   │   │   ├── 701-andromaca-safeBackup-0092.json
# │   │   │   ├── 701-andromaca-safeBackup-0093.json
# │   │   │   ├── 701-andromaca-safeBackup-0094.json
# │   │   │   ├── 701-andromaca-safeBackup-0095.json
# │   │   │   ├── 701-andromaca-safeBackup-0096.json
# │   │   │   ├── 701-andromaca-safeBackup-0097.json
# │   │   │   ├── 701-andromaca-safeBackup-0098.json
# │   │   │   ├── 701-andromaca-safeBackup-0099.json
# │   │   │   ├── 701-andromaca-safeBackup-0100.json
# │   │   │   ├── 701-andromaca-safeBackup-0101.json
# │   │   │   ├── 701-andromaca-safeBackup-0102.json
# │   │   │   ├── 701-andromaca-safeBackup-0103.json
# │   │   │   ├── 701-andromaca-safeBackup-0104.json
# │   │   │   ├── 701-andromaca-safeBackup-0105.json
# │   │   │   ├── 701-andromaca-safeBackup-0106.json
# │   │   │   ├── 701-andromaca-safeBackup-0107.json
# │   │   │   ├── 701-andromaca-safeBackup-0108.json
# │   │   │   ├── 701-andromaca-safeBackup-0109.json
# │   │   │   ├── 701-andromaca-safeBackup-0110.json
# ...
# │               │   │   │   ├── example.pdf
# │               │   │   │   ├── lapreprint.cls
# │               │   │   │   ├── LICENSE
# │               │   │   │   ├── main.tex
# │               │   │   │   ├── README.md
# │               │   │   │   └── src
# │               │   │   │       ├── bibliography.bib
# │               │   │   │       ├── chapters
# │               │   │   │       │   ├── abstract.tex
# │               │   │   │       │   ├── discussion.tex
# │               │   │   │       │   ├── formal.tex
# │               │   │   │       │   ├── introduction.tex
# │               │   │   │       │   ├── methods.tex
# │               │   │   │       │   └── results.tex
# │               │   │   │       ├── figures
# │               │   │   │       │   └── brighton.jpeg
# │               │   │   │       ├── supplementary
# │               │   │   │       │   ├── appendices.tex
# │               │   │   │       │   └── resources.tex
# │               │   │   │       └── tables
# │               │   │   │           └── simple-table.tex
# │               │   │   ├── README.md
# │               │   │   ├── template.tex
# │               │   │   ├── template.yml
# │               │   │   └── thumbnail.png
# │               │   ├── lapreprint.cls
# │               │   ├── template.tex
# │               │   ├── template.yml
# │               │   └── template.zip
# │               ├── my_latex_book
# │               │   ├── Images
# │               │   │   ├── background.pdf
# │               │   │   ├── creodocs_logo.pdf
# │               │   │   ├── orange1.jpg
# │               │   │   ├── orange2.jpg
# │               │   │   └── orange3.jpg
# │               │   ├── indexstyle.ist
# │               │   ├── LegrandOrangeBook.cls
# │               │   ├── my_latex_book-main
# │               │   │   ├── README.md
# │               │   │   ├── template.tex
# │               │   │   ├── template.yml
# │               │   │   └── thumbnail.png
# │               │   ├── sample.bib
# │               │   ├── template.tex
# │               │   ├── template.yml
# │               │   └── template.zip
# │               └── plain_latex_book
# │                   ├── plain_latex_book-main
# │                   │   ├── README.md
# │                   │   ├── template.tex
# │                   │   ├── template.yml
# │                   │   └── thumbnail.png
# │                   ├── template.tex
# │                   ├── template.yml
# │                   └── template.zip
# ├── banner.jpg
# ├── content
# │   ├── 001-index.ipynb
# │   ├── 002-tema0.ipynb
# │   ├── 100-tema1.ipynb
# │   ├── 101.ipynb
# │   ├── 102.ipynb
# │   ├── 103.ipynb
# │   ├── 104.ipynb
# │   ├── 105.ipynb
# │   ├── 300.ipynb
# │   ├── 310-tema3.ipynb
# │   ├── 320.ipynb
# │   ├── 321.ipynb
# │   ├── 322.ipynb
# │   ├── 323.ipynb
# │   ├── 700-tema7.ipynb
# │   ├── 701.ipynb
# │   ├── 702.ipynb
# │   ├── 703.ipynb
# │   ├── 704.ipynb
# │   ├── 705.ipynb
# │   └── figures
# │       ├── cameraman.png
# │       ├── citations.png
# │       ├── equations.gif
# │       ├── export-pdf.png
# │       ├── frontmatter-after.png
# │       ├── frontmatter-before.png
# │       ├── interactive.gif
# │       ├── pdf-two-column.png
# │       ├── structured-data.gif
# │       ├── T0
# │       │   ├── 1_fig10.pdf
# │       │   ├── 1_fig10.png
# │       │   ├── 1_fig11.pdf
# │       │   ├── 1_fig11.png
# │       │   ├── 1_fig2.pdf
# │       │   ├── 1_fig2.png
# │       │   ├── 1_fig3.pdf
# │       │   ├── 1_fig3.png
# │       │   ├── 1_fig4.pdf
# │       │   ├── 1_fig4.png
# │       │   ├── 1_fig5.pdf
# │       │   ├── 1_fig5.png
# │       │   ├── 1_fig6.pdf
# │       │   ├── 1_fig6.png
# │       │   ├── 1_fig7.pdf
# │       │   ├── 1_fig7.png
# │       │   ├── 1_fig8.pdf
# │       │   ├── 1_fig8.png
# │       │   ├── 1_fig9.pdf
# │       │   ├── 1_fig9.png
# │       │   ├── 2_1_fig1.pdf
# │       │   ├── 2_1_fig1.png
# │       │   ├── svg
# │       │   │   ├── 1_fig11.svg
# │       │   │   ├── 1_fig2.svg
# │       │   │   ├── 1_fig3.svg
# │       │   │   ├── 1_fig4.svg
# │       │   │   ├── 1_fig5.svg
# │       │   │   ├── 1_fig6.svg
# │       │   │   ├── 1_fig7.svg
# │       │   │   ├── 1_fig8.svg
# │       │   │   ├── 1_fig9.svg
# │       │   │   └── 2_1_fig1.svg
# │       │   └── xfig
# │       │       ├── 1_fig10.fig
# │       │       ├── 1_fig10.fig.bak
# │       │       ├── 1_fig11.fig
# │       │       ├── 1_fig2.fig
# │       │       ├── 1_fig3.fig
# │       │       ├── 1_fig4.fig
# │       │       ├── 1_fig5.fig
# │       │       ├── 1_fig6.fig
# │       │       ├── 1_fig7.fig
# │       │       ├── 1_fig8.fig
# │       │       ├── 1_fig9.fig
# │       │       └── 2_1_fig3.fig
# │       ├── T1
# │       │   ├── 2_1_fig1.pdf
# │       │   ├── 2_1_fig1.png
# │       │   ├── 2_1_fig10.pdf
# │       │   ├── 2_1_fig10.png
# │       │   ├── 2_1_fig11.pdf
# │       │   ├── 2_1_fig11.png
# │       │   ├── 2_1_fig12.pdf
# │       │   ├── 2_1_fig12.png
# │       │   ├── 2_1_fig13.pdf
# │       │   ├── 2_1_fig13.png
# │       │   ├── 2_1_fig14.pdf
# │       │   ├── 2_1_fig14.png
# │       │   ├── 2_1_fig15.pdf
# │       │   ├── 2_1_fig15.png
# │       │   ├── 2_1_fig16.pdf
# │       │   ├── 2_1_fig16.png
# │       │   ├── 2_1_fig17.pdf
# │       │   ├── 2_1_fig17.png
# │       │   ├── 2_1_fig3.pdf
# │       │   ├── 2_1_fig3.png
# │       │   ├── 2_1_fig4.pdf
# │       │   ├── 2_1_fig4.png
# │       │   ├── 2_1_fig5.pdf
# │       │   ├── 2_1_fig5.png
# │       │   ├── 2_1_fig6.pdf
# │       │   ├── 2_1_fig6.png
# │       │   ├── 2_1_fig7.pdf
# │       │   ├── 2_1_fig7.png
# │       │   ├── 2_1_fig8.pdf
# │       │   ├── 2_1_fig8.png
# │       │   ├── 2_1_fig9.pdf
# │       │   ├── 2_1_fig9.png
# │       │   ├── 2_2_fig1.pdf
# │       │   ├── 2_2_fig1.png
# │       │   ├── 2_2_fig10.pdf
# │       │   ├── 2_2_fig10.png
# │       │   ├── 2_2_fig11_a.pdf
# │       │   ├── 2_2_fig11_a.png
# │       │   ├── 2_2_fig11_b.pdf
# │       │   ├── 2_2_fig11_b.png
# │       │   ├── 2_2_fig12.pdf
# │       │   ├── 2_2_fig12.png
# │       │   ├── 2_2_fig13.pdf
# │       │   ├── 2_2_fig13.png
# │       │   ├── 2_2_fig2.pdf
# │       │   ├── 2_2_fig2.png
# │       │   ├── 2_2_fig3.pdf
# │       │   ├── 2_2_fig3.png
# │       │   ├── 2_2_fig4.pdf
# │       │   ├── 2_2_fig4.png
# │       │   ├── 2_2_fig5_a.pdf
# │       │   ├── 2_2_fig5_a.png
# │       │   ├── 2_2_fig5_b.pdf
# │       │   ├── 2_2_fig5_b.png
# │       │   ├── 2_2_fig6_a.pdf
# │       │   ├── 2_2_fig6_a.png
# │       │   ├── 2_2_fig6_b.pdf
# │       │   ├── 2_2_fig6_b.png
# │       │   ├── 2_2_fig7_a.pdf
# │       │   ├── 2_2_fig7_a.png
# │       │   ├── 2_2_fig7_b.pdf
# │       │   ├── 2_2_fig7_b.png
# │       │   ├── 2_2_fig8_a.pdf
# │       │   ├── 2_2_fig8_a.png
# │       │   ├── 2_2_fig8_b.pdf
# │       │   ├── 2_2_fig8_b.png
# │       │   ├── 2_2_fig9_a.pdf
# │       │   ├── 2_2_fig9_a.png
# │       │   ├── 2_2_fig9_b.pdf
# │       │   ├── 2_2_fig9_b.png
# │       │   ├── 2_3_fig1.pdf
# │       │   ├── 2_3_fig1.png
# │       │   ├── 2_3_fig10.pdf
# │       │   ├── 2_3_fig10.png
# │       │   ├── 2_3_fig11.pdf
# │       │   ├── 2_3_fig11.png
# │       │   ├── 2_3_fig12.pdf
# │       │   ├── 2_3_fig12.png
# │       │   ├── 2_3_fig13.pdf
# │       │   ├── 2_3_fig13.png
# │       │   ├── 2_3_fig14.pdf
# │       │   ├── 2_3_fig14.png
# │       │   ├── 2_3_fig15.pdf
# │       │   ├── 2_3_fig15.png
# │       │   ├── 2_3_fig16.pdf
# │       │   ├── 2_3_fig16.png
# │       │   ├── 2_3_fig17.pdf
# │       │   ├── 2_3_fig17.png
# │       │   ├── 2_3_fig2.pdf
# │       │   ├── 2_3_fig2.png
# │       │   ├── 2_3_fig3.pdf
# │       │   ├── 2_3_fig3.png
# │       │   ├── 2_3_fig4.pdf
# │       │   ├── 2_3_fig4.png
# │       │   ├── 2_3_fig5.pdf
# │       │   ├── 2_3_fig5.png
# │       │   ├── 2_3_fig6.pdf
# │       │   ├── 2_3_fig6.png
# │       │   ├── 2_3_fig7.pdf
# │       │   ├── 2_3_fig7.png
# │       │   ├── 2_3_fig8.pdf
# │       │   ├── 2_3_fig8.png
# │       │   ├── 2_3_fig9.pdf
# │       │   ├── 2_3_fig9.png
# │       │   ├── 2_4_fig1.pdf
# │       │   ├── 2_4_fig1.png
# │       │   ├── 2_4_fig10.pdf
# │       │   ├── 2_4_fig10.png
# │       │   ├── 2_4_fig11.pdf
# │       │   ├── 2_4_fig11.png
# │       │   ├── 2_4_fig12.pdf
# │       │   ├── 2_4_fig12.png
# │       │   ├── 2_4_fig13.pdf
# │       │   ├── 2_4_fig13.png
# │       │   ├── 2_4_fig14.pdf
# │       │   ├── 2_4_fig14.png
# │       │   ├── 2_4_fig15.pdf
# │       │   ├── 2_4_fig15.png
# │       │   ├── 2_4_fig16.pdf
# │       │   ├── 2_4_fig16.png
# │       │   ├── 2_4_fig17.pdf
# │       │   ├── 2_4_fig17.png
# │       │   ├── 2_4_fig2.pdf
# │       │   ├── 2_4_fig2.png
# │       │   ├── 2_4_fig3.pdf
# │       │   ├── 2_4_fig3.png
# │       │   ├── 2_4_fig4.pdf
# │       │   ├── 2_4_fig4.png
# │       │   ├── 2_4_fig5.pdf
# │       │   ├── 2_4_fig5.png
# │       │   ├── 2_4_fig6.pdf
# │       │   ├── 2_4_fig6.png
# │       │   ├── 2_4_fig7.pdf
# │       │   ├── 2_4_fig7.png
# │       │   ├── 2_4_fig8.pdf
# │       │   ├── 2_4_fig8.png
# │       │   ├── 2_4_fig9.pdf
# │       │   ├── 2_4_fig9.png
# │       │   ├── invertibilidad.pdf
# │       │   ├── invertibilidad.png
# │       │   ├── paralelo.pdf
# │       │   ├── paralelo.png
# │       │   ├── realimentacion.pdf
# │       │   ├── realimentacion.png
# │       │   ├── serie.pdf
# │       │   ├── serie.png
# │       │   ├── svg
# │       │   │   ├── 2_1_fig1.svg
# │       │   │   ├── 2_1_fig10.svg
# │       │   │   ├── 2_1_fig11.svg
# │       │   │   ├── 2_1_fig12.svg
# │       │   │   ├── 2_1_fig13.svg
# │       │   │   ├── 2_1_fig14.svg
# │       │   │   ├── 2_1_fig15.svg
# │       │   │   ├── 2_1_fig16.svg
# │       │   │   ├── 2_1_fig17.svg
# │       │   │   ├── 2_1_fig3.svg
# │       │   │   ├── 2_1_fig4.svg
# │       │   │   ├── 2_1_fig5.svg
# │       │   │   ├── 2_1_fig6.svg
# │       │   │   ├── 2_1_fig7.svg
# │       │   │   ├── 2_1_fig8.svg
# │       │   │   ├── 2_1_fig9.svg
# │       │   │   ├── 2_2_fig1.svg
# │       │   │   ├── 2_2_fig10.svg
# │       │   │   ├── 2_2_fig11_a.svg
# │       │   │   ├── 2_2_fig11_b.svg
# │       │   │   ├── 2_2_fig12.svg
# │       │   │   ├── 2_2_fig13.svg
# │       │   │   ├── 2_2_fig2.svg
# │       │   │   ├── 2_2_fig3.svg
# │       │   │   ├── 2_2_fig4.svg
# │       │   │   ├── 2_2_fig5_a.svg
# │       │   │   ├── 2_2_fig5_b.svg
# │       │   │   ├── 2_2_fig6_a.svg
# │       │   │   ├── 2_2_fig6_b.svg
# │       │   │   ├── 2_2_fig7_a.svg
# │       │   │   ├── 2_2_fig7_b.svg
# │       │   │   ├── 2_2_fig8_a.svg
# │       │   │   ├── 2_2_fig8_b.svg
# │       │   │   ├── 2_2_fig9_a.svg
# │       │   │   ├── 2_2_fig9_b.svg
# │       │   │   ├── 2_3_fig1.svg
# │       │   │   ├── 2_3_fig10.svg
# │       │   │   ├── 2_3_fig11.svg
# │       │   │   ├── 2_3_fig12.svg
# │       │   │   ├── 2_3_fig13.svg
# │       │   │   ├── 2_3_fig14.svg
# │       │   │   ├── 2_3_fig15.svg
# │       │   │   ├── 2_3_fig16.svg
# │       │   │   ├── 2_3_fig17.svg
# │       │   │   ├── 2_3_fig2.svg
# │       │   │   ├── 2_3_fig3.svg
# │       │   │   ├── 2_3_fig4.svg
# │       │   │   ├── 2_3_fig5.svg
# │       │   │   ├── 2_3_fig6.svg
# │       │   │   ├── 2_3_fig7.svg
# │       │   │   ├── 2_3_fig8.svg
# │       │   │   ├── 2_3_fig9.svg
# │       │   │   ├── 2_4_fig1.svg
# │       │   │   ├── 2_4_fig10.svg
# │       │   │   ├── 2_4_fig11.svg
# │       │   │   ├── 2_4_fig12.svg
# │       │   │   ├── 2_4_fig13.svg
# │       │   │   ├── 2_4_fig14.svg
# │       │   │   ├── 2_4_fig15.svg
# │       │   │   ├── 2_4_fig16.svg
# │       │   │   ├── 2_4_fig17.svg
# │       │   │   ├── 2_4_fig2.svg
# │       │   │   ├── 2_4_fig3.svg
# │       │   │   ├── 2_4_fig4.svg
# │       │   │   ├── 2_4_fig5.svg
# │       │   │   ├── 2_4_fig6.svg
# │       │   │   ├── 2_4_fig7.svg
# │       │   │   ├── 2_4_fig8.svg
# │       │   │   ├── 2_4_fig9.svg
# │       │   │   ├── invertibilidad.svg
# │       │   │   ├── paralelo.svg
# │       │   │   ├── realimentacion.svg
# │       │   │   └── serie.svg
# │       │   └── xfig
# │       │       ├── 2_1_fig1.fig
# │       │       ├── 2_1_fig10.fig
# │       │       ├── 2_1_fig11.fig
# │       │       ├── 2_1_fig12.fig
# │       │       ├── 2_1_fig13.fig
# │       │       ├── 2_1_fig14.fig
# │       │       ├── 2_1_fig15.fig
# │       │       ├── 2_1_fig16.fig
# │       │       ├── 2_1_fig17.fig
# │       │       ├── 2_1_fig3.fig
# │       │       ├── 2_1_fig4.fig
# │       │       ├── 2_1_fig5.fig
# │       │       ├── 2_1_fig6.fig
# │       │       ├── 2_1_fig7.fig
# │       │       ├── 2_1_fig8.fig
# │       │       ├── 2_1_fig9.fig
# │       │       ├── 2_2_fig1.fig
# │       │       ├── 2_2_fig10.fig
# │       │       ├── 2_2_fig11_a.fig
# │       │       ├── 2_2_fig11_b.fig
# │       │       ├── 2_2_fig12.fig
# │       │       ├── 2_2_fig13.fig
# │       │       ├── 2_2_fig2.fig
# │       │       ├── 2_2_fig3.fig
# │       │       ├── 2_2_fig4.fig
# │       │       ├── 2_2_fig5_a.fig
# │       │       ├── 2_2_fig5_b.fig
# │       │       ├── 2_2_fig6_a.fig
# │       │       ├── 2_2_fig6_b.fig
# │       │       ├── 2_2_fig7_a.fig
# │       │       ├── 2_2_fig7_b.fig
# │       │       ├── 2_2_fig8_a.fig
# │       │       ├── 2_2_fig8_b.fig
# │       │       ├── 2_2_fig9_a.fig
# │       │       ├── 2_2_fig9_b.fig
# │       │       ├── 2_3_fig1.fig
# │       │       ├── 2_3_fig10.fig
# │       │       ├── 2_3_fig11.fig
# │       │       ├── 2_3_fig12.fig
# │       │       ├── 2_3_fig13.fig
# │       │       ├── 2_3_fig14.fig
# │       │       ├── 2_3_fig15.fig
# │       │       ├── 2_3_fig16.fig
# │       │       ├── 2_3_fig17.fig
# │       │       ├── 2_3_fig2.fig
# │       │       ├── 2_3_fig3.fig
# │       │       ├── 2_3_fig4.fig
# │       │       ├── 2_3_fig5.fig
# │       │       ├── 2_3_fig6.fig
# │       │       ├── 2_3_fig7.fig
# │       │       ├── 2_3_fig8.fig
# │       │       ├── 2_3_fig9.fig
# │       │       ├── 2_4_fig1.fig
# │       │       ├── 2_4_fig10.fig
# │       │       ├── 2_4_fig11.fig
# │       │       ├── 2_4_fig12.fig
# │       │       ├── 2_4_fig13.fig
# │       │       ├── 2_4_fig14.fig
# │       │       ├── 2_4_fig15.fig
# │       │       ├── 2_4_fig16.fig
# │       │       ├── 2_4_fig17.fig
# │       │       ├── 2_4_fig2.fig
# │       │       ├── 2_4_fig3.fig
# │       │       ├── 2_4_fig4.fig
# │       │       ├── 2_4_fig5.fig
# │       │       ├── 2_4_fig6.fig
# │       │       ├── 2_4_fig7.fig
# │       │       ├── 2_4_fig8.fig
# │       │       ├── 2_4_fig9.fig
# │       │       ├── invertibilidad.fig
# │       │       ├── paralelo.fig
# │       │       ├── realimentacion.fig
# │       │       └── serie.fig
# │       ├── T3
# │       │   ├── audio.svg
# │       │   ├── diag0.svg
# │       │   ├── diag_autofuncion.svg
# │       │   ├── diag_autofuncion2.svg
# │       │   ├── electrocardiograma.jpg
# │       │   ├── exp_rel_armonicamente.svg
# │       │   ├── figuras.ipynb
# │       │   ├── mi_voz.mp3
# │       │   └── signal_periodic.svg
# │       └── T7
# │           ├── anticausal_ROC_left.png
# │           ├── causal_ROC_right.png
# │           ├── example1_ROC.png
# │           ├── example1_ROC_r1.png
# │           ├── example1_zero_pole.png
# │           ├── example2_ROC.png
# │           ├── example2_ROC_r1.png
# │           ├── example2_zero_pole.png
# │           ├── example3_ring.png
# │           ├── example3_ROC_left.png
# │           ├── example3_ROC_right.png
# │           ├── example4_inverse_anticausal.png
# │           ├── example4_inverse_causal.png
# │           ├── example5_anticausal.png
# │           ├── example5_causal.png
# │           ├── example5_ring.png
# │           ├── nonstable_anticausal.png
# │           ├── ring1_ROC.png
# │           ├── stable_causal.png
# │           ├── stable_ring.png
# │           ├── svg
# │           │   ├── anticausal_ROC_left.svg
# │           │   ├── causal_ROC_right.svg
# │           │   ├── example1_ROC_r1.svg
# │           │   ├── example2_ROC_r1.svg
# │           │   ├── example3_ring.svg
# │           │   ├── example3_ROC_left.svg
# │           │   ├── example3_ROC_right.svg
# │           │   ├── example4_inverse_anticausal.svg
# │           │   ├── example4_inverse_causal.svg
# │           │   ├── example5_anticausal.svg
# │           │   ├── example5_causal.svg
# │           │   ├── example5_ring.svg
# │           │   ├── nonstable_anticausal.svg
# │           │   ├── stable_causal.svg
# │           │   ├── stable_ring.svg
# │           │   └── z_plane.svg
# │           ├── table1_Z_transform.png
# │           ├── table2_Z_transform.png
# │           └── z_plane.png
# ├── exports
# │   └── sistemas_lineales.pdf
# ├── favicon.png
# ├── index.md
# ├── myst.yml
# ├── README.md
# ├── requirements.txt
# ├── site_logo.png
# ├── tools
# │   ├── inkscape-pdf2svg.sh
# │   ├── pdf2png-batch.sh
# │   ├── pdf2svg-batch.sh
# │   └── xfig_convert.sh
# ├── tutorial
# │   └── 02-notebook.ipynb
# └── typst.exe
