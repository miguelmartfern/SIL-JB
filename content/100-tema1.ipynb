# %% [markdown]
# ---
# title: Parte I – Introducción a los sistemas lineales
# ---
#
# ```{raw:latex}
# \part{Parte I – Introducción a los sistemas lineales}
# ```

# %% [markdown]
# En este tema vamos a describir el lenguaje matemático que nos permitirá desarrollar herramientas muy poderosas para analizar señales y sistemas en muy diversos campos.
